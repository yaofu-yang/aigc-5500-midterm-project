# %% [markdown]
# # Midterm Project
# - AIGC 5500 0NA
# - Advanced Deep Learning
# - Summer 2026
#
#
# ### Team Info
# HawkAI Detection | Group 1
# | Name | Github |
# | --- | --- |
# | Kevin Joseff Cabrera (Kevin) | https://github.com/kjcabPL |
# | Mohd Mujtaba Saighani (Mujtaba) | https://github.com/saigha1 |
# | Thiago Segantini Nogeuira (Thiago) | https://github.com/thiaseg |
# | Sayamon Sittiprom (Saya) | https://github.com/sittiprom |
# | Yao-Fu Yang (Andy) | https://github.com/yaofu-yang |

# %% [markdown]
# ### 1. Overview (Project Instructions)
# In the activation functions and gradient descent module, you studied variations of gradient descent
# and the hyperparameters that govern training dynamics. This project puts that knowledge to work:
# you will systematically compare three modern optimizers on a real image-classification task, analyze
# how each one behaves under different hyperparameter settings, and communicate your findings in a
# live group presentation.
# - Objective: Implement, tune, and compare Adam, RMSprop, and AdamW on a feedforward
# neural network trained on the KMNIST dataset, and draw evidence-based conclusions about
# their relative strengths and trade-offs.
# - Importance: Choosing the wrong optimizer or leaving hyperparameters at default values is
# one of the most common causes of poor model performance. This project builds the analytical
# habits you will carry into every future deep learning task.

# %% [markdown]
# ### 2. Dataset (Project Instructions)
# Use the KMNIST (Kuzushiji-MNIST) dataset, available directly through PyTorch:
# | Property | Details |
# |---|---|
# |Training Samples| 60,000 Images|
# |Test Samples| 10,000 Images|
# |Image Size | 28 x 28 Pixels, Greyscale|
# |Classes| 10 (Japanese Hiragana Characters)|
# |Complexity| Higher than MNIST; class boundaries overlap|

# %%
# Handle all imports first
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

# Kuzushiji-MNIST Dataset
from torchvision.datasets import KMNIST
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import KFold
from typing import Type, Dict, Any, Callable
import numpy as np
from matplotlib import pyplot as plt
import time

# %%
# Define data preparation constants
MANUAL_SEED = 498
ROOT ='./kuzushiji_data'

# %%
# Load the data and complete basic exploration

# Setting the random seed
torch.manual_seed(MANUAL_SEED)

# Use GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load Training data as a single batch to compute mean and standard deviation
# Define a transformation to Tensor
transform = transforms.Compose([transforms.ToTensor()])
trainset = KMNIST(root=ROOT, train=True, download=True, transform=transform)
trainloader = DataLoader(trainset, batch_size=len(trainset), shuffle=True)
data = next(iter(trainloader))
mean = data[0].mean().item()
stddev = data[0].std().item()
print(f"The mean is : {mean}")
print(f"The standard deviation is: {stddev}")
# Out:
# Using device: cuda
# The mean is : 0.19176216423511505
# The standard deviation is: 0.3483428359031677

# %%
# Check data shape
# (Batch Size, Channel Counts, Row Pixels, Column Pixels)
data[0].size()
# Out:
# torch.Size([60000, 1, 28, 28])

# %%
# Prepare the data

# Apply Input Standardization to reduce risk of saturating neurons
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize([mean], [stddev])])

# Create training and testing sets while applying standardization
trainset = KMNIST(root=ROOT, train=True, download=True, transform=transform)
testset = KMNIST(root=ROOT, train=False, download=True, transform=transform)


# Verify final dimension of all three data sets
print(f"Train set size: {len(trainset)}")
print(f"Test set size: {len(testset)}")
# Out:
# Train set size: 60000
# Test set size: 10000

# %% [markdown]
# # 3. Model Architecture (Project Instructions)
# Implement the following feedforward fully-connected architecture. Do not modify it; the architecture is fixed so that all differences between runs are attributable to the optimizer and its hyperparameters.
#
# |Layer|Configuration|Notes
# |---|---|---|
# |Input|784 Neurons|Flatten 28x28 image|
# |Hidden 1|128 Neurons, ReLU Activation||
# |Hidden 1|64 Neurons, ReLU Activation||
# |Output|10 Neurons, Softmax activation|One neuron per class|
# |Loss function|Cross-Entropy Loss|Appropriate for multi-class classification|

# %%
# Define architectural constants
INPUT_DIM = 784  # Cannot change
HIDDEN_DIM1 = 128  # Cannot change
HIDDEN_DIM2 = 64  # Cannot change
OUTPUT_DIM = 10  # Cannot change

# %%
# Define the forward pass. Final activation is omitted since softmax is part of
# cross-entropy loss function in PyTorch.
class FeedForwardNet(nn.Module):
    def __init__(
        self,
        input_dim:  int = INPUT_DIM,
        hidden_dim1: int = HIDDEN_DIM1,
        hidden_dim2: int = HIDDEN_DIM2,
        output_dim: int = OUTPUT_DIM
    ) -> None:
        super().__init__()
        # First Hidden Layer
        self.hidden1 = nn.Linear(input_dim, hidden_dim1)
        # Apply BatchNorm to first hidden layer
        self.batchNorm1 = nn.BatchNorm1d(num_features=hidden_dim1)
        # Apply random deactivation of neurons to reduce overfitting
        self.dropout1 = nn.Dropout(p=0.2)

        # Second Hidden Layer
        self.hidden2 = nn.Linear(hidden_dim1, hidden_dim2)
        # Apply BatchNorm to second hidden layer
        self.batchNorm2 = nn.BatchNorm1d(num_features=hidden_dim2)
        # Apply random deactivation of neurons to reduce overfitting
        self.dropout2 = nn.Dropout(p=0.2)

        # Final Output Layer
        self.output = nn.Linear(hidden_dim2, output_dim)

        # Customized function to initialize weights for each layer.
        self._initialize_weights()

    # Applies Weight Initialization technique.
    def _initialize_weights(self) -> None:
        # Kaiming (He) initialization for first hidden layer
        nn.init.kaiming_normal_(self.hidden1.weight, nonlinearity='relu')
        nn.init.constant_(self.hidden1.bias, 0.0)

        # Same for second hidden layer
        nn.init.kaiming_normal_(self.hidden2.weight, nonlinearity='relu')
        nn.init.constant_(self.hidden2.bias, 0.0)

        # Xavier (Glorot) initialization for the output layer (no activation).
        nn.init.xavier_uniform_(self.output.weight)
        nn.init.constant_(self.output.bias, 0.0)

    # Completes the forward pass
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # Flatten the image from 28x28 to 784 pixels
        x = torch.flatten(x, start_dim=1)

        # First layers (hidden, batchnorm, relu activation, dropout)
        x = self.hidden1(x)
        x = self.batchNorm1(x)
        x = F.relu(x)
        x = self.dropout1(x)

        # Second Layers (hidden, batchnorm, relu activation, dropout)
        x = self.hidden2(x)
        x = self.batchNorm2(x)
        x = F.relu(x)
        x = self.dropout2(x)

        return self.output(x)    # Raw logits; softmax applied by loss function.

# Initializes the model.
model = FeedForwardNet()

# %% [markdown]
# # 4. Optimizers Under Investigation (Project Instructions)
# You will train and evaluate the same fixed architecture using each of the three optimizers below. For
# every optimizer, perform a structured hyperparameter search (see Section 5) and report results for
# both the default configuration and the best configuration found.
#
# ### 4.1  Adam (Adaptive Moment Estimation)
# - Key idea: Maintains separate adaptive learning rates for each parameter by combining first-
# moment (momentum) and second-moment (uncentred variance) estimates.
# - Default settings: lr = 0.001, β1 = 0.9, β2 = 0.999, ε = 1e-8.
# - Investigate: The effect of learning rate and β1 on convergence speed and final accuracy.
#
# ### 4.2  RMSprop (Root Mean Square Propagation)
# - Key idea: Divides the learning rate by a running average of the squared gradient magnitudes,
# preventing updates from growing too large.
# - Default settings: lr = 0.01, α = 0.99, ε = 1e-8.
# - Investigate: The effect of the decay factor α and learning rate on training stability.
#
# ### 4.3  AdamW (Adam with Decoupled Weight Decay)
# - Key  idea:  Corrects a known flaw in Adam’s L2 regularization by decoupling weight decay
# from the adaptive learning-rate update, leading to better generalization.
# - Default settings: lr = 0.001, β1 = 0.9, β2 = 0.999, ε = 1e-8, weight_decay = 0.01.
# - Investigate: The effect of weight_decay and learning rate on the gap between training and
# test accuracy.

# %% [markdown]
# ### Branch TODO 1: Research the Assigned Optimizer
# The project instructions give a brief overview of the key ideas, default settings, and investigation pathways for each optimizer. Start by completing the investigation tasks but go deeper to find other intereting and unique parameters/features of each optimizer (including ones not covered in lecture).
#
# Action Item: Add a document in the branch with the findings, or include the findings directly in the notebook. For reference, the final PDF report requires the following: "Optimizer descriptions and theoretical background"

# %% [markdown]
# ### Adam (Adaptive Moment Estimation) — Research Findings
#
# **Key Idea:**
# Adam (Kingma & Ba, 2015) combines two well-known optimization techniques: momentum and RMSprop. It maintains two running averages for each parameter — the first moment (mean of gradients, like momentum) and the second moment (mean of squared gradients, like RMSprop). This allows Adam to compute an adaptive learning rate for each individual parameter, making it well-suited for problems with sparse gradients or noisy data.
#
# **Default Parameters:**
# - `lr = 0.001` — the global learning rate (step size)
# - `β1 = 0.9` — decay rate for the first moment (momentum). Controls how much past gradients influence the current update.
# - `β2 = 0.999` — decay rate for the second moment. Controls how much past squared gradients influence the scaling.
# - `ε = 1e-8` — small constant to prevent division by zero.
#
# **Additional Features (beyond lecture):**
# - Adam includes **bias correction** in the first few iterations, which prevents the moment estimates from being too small at the start of training.
# - The `weight_decay` parameter can be added to Adam, but it is applied in a coupled way (unlike AdamW, which decouples it). This is a known limitation of Adam's L2 regularization.
# - Adam is generally robust to the choice of learning rate compared to SGD, but it can sometimes converge to sharp minima that generalize less well.
#
# **Investigation Plan:**
# I will investigate the effect of `lr` and `β1` on convergence speed and final accuracy by testing four configurations:
# - Config 1 (default): `lr=0.001`, `β1=0.9`
# - Config 2 (higher lr): `lr=0.01`, `β1=0.9`
# - Config 3 (lower lr): `lr=0.0001`, `β1=0.9`
# - Config 4 (lower β1): `lr=0.001`, `β1=0.8`

# %%
# Define adjustable constants
EPOCHS = 20  # Min 20
BATCH_SIZE = 64  # May change
K_FOLD = 5 # Cannot change
TARGET_ACC = 0.6 # Will change

# %% [markdown]
# # Methodology (Project Instructions)
# ### 5.1  Hyperparameter Search
# For each optimizer, evaluate at least four (4) distinct hyperparameter configurations. You may use
# grid search, random search, or a manual systematic approach. Document your search strategy and
# justify your final selection.
#
# At minimum, vary the following for each optimizer:
# - Learning  rate: try values  spanning  at  least  two  orders  of magnitude (e.g.,  0.1,  0.01,  0.001,
# 0.0001).
# - At least one optimizer-specific hyperparameter (e.g., β1 for Adam/AdamW, decay factor for
# RMSprop).
#
# ### 5.2  Cross-Validation
# - Apply 5-fold cross-validation on the training set to estimate generalization performance.
# - Report  the  mean  and  standard  deviation  of  validation  accuracy  across  folds  for  each
# configuration.
# - Use the best configuration identified through cross-validation to train a final model on the full
# training set.
#
# ### 5.3  Training Protocol
# - Train  for  a  fixed  number  of  epochs  (minimum  20)  across  all  configurations  to  ensure  fair
# comparison.
# - Use the same random seed for all runs to control for initialization variance.
# - Record training loss, validation loss, and validation accuracy at each epoch.
# - Evaluate the final model on the held-out test set; report test accuracy and test loss.
#
# ### 5.4  Metrics to Record
# |Metric|Description|
# |---|---|
# |Training Accuracy|Accuracy on the training set at the final epoch|
# |Validation Accuracy|Mean cross-validation accuracy (and std dev) across 5 folds|
# |Test Accuracy|Accuracy on the held-out test set |
# |Final Loss|Training and test loss at the end of training|
# |Convergence Speed|Number of epochs to reach a target validation accuracy (e.g.,
# 80%)|
# |Training Time|Wall-clock time for a full training run|

# %%
# Define a reusable run Epoch function for both training & evaluation loops
def run_epoch(
    model:     nn.Module,
    loader:    DataLoader,
    criterion: nn.Module,
    optimizer: torch.optim.Optimizer | None,
    device:    torch.device,
    training:  bool,
) -> tuple[float, float]:
    """Run one full pass over the DataLoader.
    Pass optimizer=None during evaluation.
    Returns (mean loss, accuracy).
    """
    model.train() if training else model.eval()

    total_loss    = 0.0
    total_correct = 0
    total_samples = 0

    # No gradient/back propagation if in evaluation mode.
    context = torch.enable_grad() if training else torch.no_grad()

    with context:
        for inputs, targets in loader:
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = model(inputs)
            # Cross-entropy loss does not need one-hot targets in PyTorch.
            loss = criterion(outputs, targets)

            # Only run for training mode. Evaluation mode skips this.
            if training:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            # Accumulate metrics.
            _, predicted   = torch.max(outputs, dim=1)
            total_correct += (predicted == targets).sum().item()
            total_samples += targets.size(0)
            total_loss    += loss.item()

    return total_loss / len(loader), total_correct / total_samples

# %%
# Define a reusable k-fold cross-validation function for different optimizers
# Handles the requirements in 5.2 Cross Validation & 5.3 Training Protocol

def cross_validate_config(
    model_class: Callable[[], nn.Module],  # Need a fresh model for each fold
    train_dataset: Any,
    optimizer_class: Type[torch.optim.Optimizer],  # Type of optimizer
    optimizer_kwargs: Dict[str, Any],  # Hyperparameters
    criterion: nn.Module,
    device: torch.device,
    epochs: int = EPOCHS,  # 5.3 Req, min 20 Epochs
    batch_size: int = BATCH_SIZE,
    n_splits: int = K_FOLD,  # 5.2 Req: 5-fold
    random_seed: int = MANUAL_SEED,

) -> tuple[float, float]:
    """
    Performs K-Fold Cross-Validation for a given model, optimizer, and hyperparameter configuration.
    
    Returns:
        dictionary: {
        "mean_accuracy", --> Represents mean validation accuracy 
        "std_accuracy", --> Represents standard deviation of validaion accuracy
        }
    """
    k_fold = KFold(n_splits=n_splits, shuffle=True, random_state=random_seed)
    fold_best_accuracies = []
    fold_train_times = []
    
    for fold, (train_idx, val_idx) in enumerate(k_fold.split(train_dataset)):
        # 5.3 Req: Use the same random seed for all runs to control for initialization variance.
        torch.manual_seed(random_seed)

        # Add time recording for each training fold
        fold_start_time = time.perf_counter()
        
        # Move model to device
        model = model_class().to(device)
        
        # Create optimizer using the class and parameter arguments
        optimizer = optimizer_class(model.parameters(), **optimizer_kwargs)
        
        # Generate the training folds and validation fold
        train_sub = Subset(train_dataset, train_idx)
        val_sub   = Subset(train_dataset, val_idx)
        
        # Generate the training and validation loaders
        trainloader = DataLoader(train_sub, batch_size=batch_size, shuffle=True)
        valloader   = DataLoader(val_sub, batch_size=batch_size, shuffle=False)
        
        # For tracking accuracy
        best_fold_val_acc = 0.0
        
        # Complete the training and validation per Epoch and capture metrics
        for epoch in range(epochs):
            # Training loop with the training loss and training accuracy
            train_loss, train_acc = run_epoch(
                model, trainloader, criterion, optimizer, device, training=True
            )

            # Validation loop with the validation loss and validation accuracy
            # No optimizers needed for validation, training pathway should not be run
            val_loss, val_acc = run_epoch(
                model, valloader, criterion, optimizer=None, device=device, training=False
            )
            
            # Update the best validation accuracy
            if val_acc > best_fold_val_acc:
                best_fold_val_acc = val_acc

             # Record training time for current fold
            fold_end_time = time.perf_counter()
            fold_train_time = (fold_end_time - fold_start_time) / 60 # Converted to minutes

            # Report Epoch & Losses/Accuracies
            # print(f"Fold {fold + 1}/{n_splits} Epoch {epoch + 1}/{epochs}")
            print(f"Fold {fold + 1}/{n_splits} Epoch {epoch + 1}/{epochs} | Training Accuracy: {(train_acc * 100):.2f}% | Validation Accuracy: {(val_acc * 100):.2f}%")
        
        # Tracking validation accuracies
        fold_best_accuracies.append(best_fold_val_acc)
        print(f"    Fold {fold + 1} Best Val Acc: {best_fold_val_acc:.4f}")
        print(f"    Fold {fold + 1} Total Training Time: {fold_train_time:.2f} mins.")
    # Calculate aggregated statistics
    acc_tensor = torch.tensor(fold_best_accuracies)

    # 5.2 Req: report mean and standard deviation of validation accuracies
    # Needed for 6.2 plotting accuracy distribution as well.
    return acc_tensor.mean().item(), acc_tensor.std().item()

# %% [markdown]
# # Branch TODO 2
# Modify the code below for your selected optimizer (Adam, RMSProp, AdamW).
# Make sure to include the hyperparameter changes that were identified in TODO 1/Section 4.
# Consider also changing the architecture to use Optuna or Ray Tune as discussed in lecture.
# The reusable cross-validation function should be compatible with both approaches, but feel free to modify the function with design improvements, etc.

# %%
# Example code for optimizer trials with different hyperparameter configurations

# Using Adam as the example
optimizer_name = "Adam"
optimizer_class = torch.optim.Adam

# Define sample hyperparamters.
# To fulfill requirements, need to have four unique configurations
hyperparameters = [
    {"lr": 0.001, "betas": (0.9, 0.999), "weight_decay": 1e-4},    # Config 1 — standard with low decay
    {"lr": 0.01,  "betas": (0.9, 0.999), "weight_decay": 1e-3},    # Config 2 — higher learning rate and decay
    {"lr": 0.0001,"betas": (0.9, 0.999), "weight_decay": 0.0},     # Config 3 — lower learning rate, no decay
    {"lr": 0.001, "betas": (0.8, 0.999), "weight_decay": 1e-2},    # Config 4 — lower beta1, aggressive decay
]

# Will store the results from the best configuration for this optimizer
best_configuration_results = {}

# Define evaluation metrics
best_config_score = -1.0
best_config_data = None
best_config_params = None

for config_idx, config_kwargs in enumerate(hyperparameters):
    # Example: Testing config 1/1: {"lr": 0.1, "weight_decay": 1e-4}
    print(f"Testing config {config_idx + 1}/{len(hyperparameters)}: {config_kwargs}")

    # Invoke the Cross-Validation function defined earlier
    result = cross_validate_config(
        model_class=FeedForwardNet,
        train_dataset=trainset,
        optimizer_class=optimizer_class,
        optimizer_kwargs=config_kwargs,
        criterion=nn.CrossEntropyLoss(),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        device=device
    )

    # Check and update for best results based on accuracy mean
    if result[0] > best_config_score:
        best_config_score = result[0]
        best_config_data = result
        best_config_params = config_kwargs

# This will be used for plotting later.
best_configuration_results[optimizer_name] = {
    "params": best_config_params,
    "metrics": best_config_data,
}

print(f"Best configuration: {best_config_params}")
print(f"Mean Validation Accuracy: {best_config_score:.4f}")
# Out:
# Testing config 1/4: {'lr': 0.001, 'betas': (0.9, 0.999), 'weight_decay': 0.0001}
# Fold 1/5 Epoch 1/20 | Training Accuracy: 80.29% | Validation Accuracy: 90.43%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 88.26% | Validation Accuracy: 92.12%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 90.41% | Validation Accuracy: 93.44%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 91.62% | Validation Accuracy: 94.05%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 92.15% | Validation Accuracy: 94.07%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 93.09% | Validation Accuracy: 94.50%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 93.44% | Validation Accuracy: 94.92%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 93.58% | Validation Accuracy: 94.83%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 93.80% | Validation Accuracy: 95.11%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 94.27% | Validation Accuracy: 95.23%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 94.43% | Validation Accuracy: 94.98%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 94.60% | Validation Accuracy: 95.09%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 94.71% | Validation Accuracy: 95.28%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 94.91% | Validation Accuracy: 95.24%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 95.00% | Validation Accuracy: 95.28%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 95.19% | Validation Accuracy: 95.47%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 95.08% | Validation Accuracy: 95.39%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 95.50% | Validation Accuracy: 95.59%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 95.23% | Validation Accuracy: 95.23%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 95.53% | Validation Accuracy: 95.58%
#     Fold 1 Best Val Acc: 0.9559
#     Fold 1 Total Training Time: 3.01 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 80.47% | Validation Accuracy: 90.72%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 88.35% | Validation Accuracy: 92.22%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 90.41% | Validation Accuracy: 93.42%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 91.67% | Validation Accuracy: 94.23%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 92.34% | Validation Accuracy: 94.69%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 92.98% | Validation Accuracy: 95.10%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 93.45% | Validation Accuracy: 95.00%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 93.85% | Validation Accuracy: 95.17%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 94.00% | Validation Accuracy: 95.23%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 94.11% | Validation Accuracy: 95.08%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 94.47% | Validation Accuracy: 95.36%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 94.71% | Validation Accuracy: 95.49%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 94.82% | Validation Accuracy: 95.35%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 95.09% | Validation Accuracy: 95.36%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 95.02% | Validation Accuracy: 95.28%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 95.10% | Validation Accuracy: 95.51%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 95.20% | Validation Accuracy: 95.67%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 95.39% | Validation Accuracy: 95.45%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 95.31% | Validation Accuracy: 95.32%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 95.52% | Validation Accuracy: 95.50%
#     Fold 2 Best Val Acc: 0.9567
#     Fold 2 Total Training Time: 3.02 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 80.12% | Validation Accuracy: 91.35%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 88.34% | Validation Accuracy: 92.92%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 90.42% | Validation Accuracy: 93.56%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 91.32% | Validation Accuracy: 94.25%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 92.31% | Validation Accuracy: 94.76%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 92.90% | Validation Accuracy: 95.15%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 93.22% | Validation Accuracy: 95.25%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 93.66% | Validation Accuracy: 95.32%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 93.92% | Validation Accuracy: 95.59%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 94.34% | Validation Accuracy: 95.54%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 94.48% | Validation Accuracy: 95.75%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 94.47% | Validation Accuracy: 95.61%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 94.70% | Validation Accuracy: 95.62%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 94.94% | Validation Accuracy: 95.80%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 95.19% | Validation Accuracy: 95.76%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 95.10% | Validation Accuracy: 95.70%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 95.24% | Validation Accuracy: 95.80%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 95.53% | Validation Accuracy: 95.71%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 95.47% | Validation Accuracy: 95.78%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 95.46% | Validation Accuracy: 95.78%
#     Fold 3 Best Val Acc: 0.9580
#     Fold 3 Total Training Time: 3.02 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 80.30% | Validation Accuracy: 91.03%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 88.29% | Validation Accuracy: 92.94%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 90.14% | Validation Accuracy: 94.04%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 91.44% | Validation Accuracy: 94.35%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 92.29% | Validation Accuracy: 94.80%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 92.82% | Validation Accuracy: 95.03%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 93.36% | Validation Accuracy: 95.50%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 93.74% | Validation Accuracy: 95.11%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 93.97% | Validation Accuracy: 95.36%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 94.15% | Validation Accuracy: 95.28%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 94.29% | Validation Accuracy: 95.29%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 94.58% | Validation Accuracy: 95.38%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 94.74% | Validation Accuracy: 95.39%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 94.81% | Validation Accuracy: 95.44%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 94.89% | Validation Accuracy: 95.62%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 94.91% | Validation Accuracy: 95.45%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 95.18% | Validation Accuracy: 95.62%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 95.40% | Validation Accuracy: 95.62%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 95.28% | Validation Accuracy: 95.50%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 95.24% | Validation Accuracy: 95.67%
#     Fold 4 Best Val Acc: 0.9567
#     Fold 4 Total Training Time: 3.00 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 80.23% | Validation Accuracy: 90.86%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 88.19% | Validation Accuracy: 92.62%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 90.50% | Validation Accuracy: 93.85%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 91.71% | Validation Accuracy: 94.04%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 92.31% | Validation Accuracy: 94.42%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 92.99% | Validation Accuracy: 94.50%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 93.40% | Validation Accuracy: 94.66%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 93.61% | Validation Accuracy: 94.98%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 94.01% | Validation Accuracy: 94.81%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 94.15% | Validation Accuracy: 95.03%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 94.68% | Validation Accuracy: 95.22%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 94.75% | Validation Accuracy: 95.16%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 94.80% | Validation Accuracy: 95.25%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 94.97% | Validation Accuracy: 95.12%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 95.11% | Validation Accuracy: 95.12%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 95.33% | Validation Accuracy: 95.16%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 95.35% | Validation Accuracy: 95.32%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 95.47% | Validation Accuracy: 95.23%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 95.37% | Validation Accuracy: 95.32%
# Fold 5/5 Epoch 20/20 | Training Accuracy: 95.49% | Validation Accuracy: 95.11%
#     Fold 5 Best Val Acc: 0.9532
#     Fold 5 Total Training Time: 3.00 mins.
# Testing config 2/4: {'lr': 0.01, 'betas': (0.9, 0.999), 'weight_decay': 0.001}
# Fold 1/5 Epoch 1/20 | Training Accuracy: 81.26% | Validation Accuracy: 86.77%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 83.73% | Validation Accuracy: 87.63%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 83.76% | Validation Accuracy: 87.92%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 83.95% | Validation Accuracy: 87.63%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 83.88% | Validation Accuracy: 88.12%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 84.09% | Validation Accuracy: 88.12%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 83.85% | Validation Accuracy: 88.42%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 83.61% | Validation Accuracy: 87.68%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 83.72% | Validation Accuracy: 87.84%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 83.74% | Validation Accuracy: 87.00%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 83.58% | Validation Accuracy: 87.38%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 83.85% | Validation Accuracy: 88.23%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 83.77% | Validation Accuracy: 87.73%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 83.70% | Validation Accuracy: 88.59%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 83.86% | Validation Accuracy: 87.34%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 83.74% | Validation Accuracy: 88.52%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 83.81% | Validation Accuracy: 88.01%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 83.87% | Validation Accuracy: 87.27%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 83.71% | Validation Accuracy: 87.57%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 83.95% | Validation Accuracy: 86.98%
#     Fold 1 Best Val Acc: 0.8859
#     Fold 1 Total Training Time: 3.02 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 81.31% | Validation Accuracy: 87.07%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 83.80% | Validation Accuracy: 87.92%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 83.88% | Validation Accuracy: 87.82%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 83.71% | Validation Accuracy: 88.16%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 83.80% | Validation Accuracy: 88.12%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 83.65% | Validation Accuracy: 88.34%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 83.91% | Validation Accuracy: 88.27%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 83.96% | Validation Accuracy: 88.04%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 83.86% | Validation Accuracy: 87.76%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 83.65% | Validation Accuracy: 87.38%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 84.00% | Validation Accuracy: 88.25%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 83.89% | Validation Accuracy: 88.48%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 83.88% | Validation Accuracy: 88.89%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 84.02% | Validation Accuracy: 88.09%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 83.84% | Validation Accuracy: 88.54%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 83.81% | Validation Accuracy: 87.78%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 83.88% | Validation Accuracy: 87.02%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 83.99% | Validation Accuracy: 88.86%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 83.81% | Validation Accuracy: 88.50%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 83.68% | Validation Accuracy: 87.92%
#     Fold 2 Best Val Acc: 0.8889
#     Fold 2 Total Training Time: 3.01 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 81.23% | Validation Accuracy: 87.60%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 83.65% | Validation Accuracy: 88.61%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 83.71% | Validation Accuracy: 88.31%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 83.43% | Validation Accuracy: 88.98%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 83.81% | Validation Accuracy: 87.78%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 83.79% | Validation Accuracy: 87.49%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 83.85% | Validation Accuracy: 88.02%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 83.77% | Validation Accuracy: 88.02%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 83.50% | Validation Accuracy: 89.38%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 83.49% | Validation Accuracy: 87.50%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 83.54% | Validation Accuracy: 88.96%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 83.67% | Validation Accuracy: 87.48%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 83.61% | Validation Accuracy: 88.75%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 83.75% | Validation Accuracy: 88.58%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 83.82% | Validation Accuracy: 88.44%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 83.65% | Validation Accuracy: 87.48%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 83.79% | Validation Accuracy: 89.77%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 83.69% | Validation Accuracy: 87.84%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 83.74% | Validation Accuracy: 89.43%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 83.42% | Validation Accuracy: 88.20%
#     Fold 3 Best Val Acc: 0.8977
#     Fold 3 Total Training Time: 3.01 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 81.37% | Validation Accuracy: 88.04%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 83.45% | Validation Accuracy: 89.07%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 83.46% | Validation Accuracy: 87.75%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 83.71% | Validation Accuracy: 88.67%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 83.88% | Validation Accuracy: 89.11%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 83.84% | Validation Accuracy: 88.46%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 83.51% | Validation Accuracy: 89.00%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 83.40% | Validation Accuracy: 88.39%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 83.54% | Validation Accuracy: 87.35%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 83.53% | Validation Accuracy: 88.38%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 83.61% | Validation Accuracy: 88.62%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 83.49% | Validation Accuracy: 89.50%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 83.96% | Validation Accuracy: 89.19%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 83.90% | Validation Accuracy: 88.88%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 83.32% | Validation Accuracy: 87.98%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 83.72% | Validation Accuracy: 89.57%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 83.73% | Validation Accuracy: 87.81%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 83.54% | Validation Accuracy: 88.19%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 83.74% | Validation Accuracy: 87.42%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 83.65% | Validation Accuracy: 89.11%
#     Fold 4 Best Val Acc: 0.8957
#     Fold 4 Total Training Time: 3.00 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 81.36% | Validation Accuracy: 88.05%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 83.67% | Validation Accuracy: 87.72%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 84.00% | Validation Accuracy: 87.35%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 83.80% | Validation Accuracy: 88.60%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 83.78% | Validation Accuracy: 88.20%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 83.65% | Validation Accuracy: 87.75%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 83.69% | Validation Accuracy: 89.08%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 83.51% | Validation Accuracy: 88.48%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 83.66% | Validation Accuracy: 88.28%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 83.90% | Validation Accuracy: 88.36%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 83.69% | Validation Accuracy: 86.65%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 83.69% | Validation Accuracy: 87.69%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 83.74% | Validation Accuracy: 88.40%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 83.63% | Validation Accuracy: 88.66%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 83.86% | Validation Accuracy: 88.98%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 83.85% | Validation Accuracy: 89.46%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 83.68% | Validation Accuracy: 88.72%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 83.76% | Validation Accuracy: 87.08%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 83.78% | Validation Accuracy: 88.04%
# Fold 5/5 Epoch 20/20 | Training Accuracy: 83.99% | Validation Accuracy: 88.22%
#     Fold 5 Best Val Acc: 0.8946
#     Fold 5 Total Training Time: 3.36 mins.
# Testing config 3/4: {'lr': 0.0001, 'betas': (0.9, 0.999), 'weight_decay': 0.0}
# Fold 1/5 Epoch 1/20 | Training Accuracy: 58.93% | Validation Accuracy: 79.76%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 77.59% | Validation Accuracy: 84.33%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 81.49% | Validation Accuracy: 86.59%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 83.78% | Validation Accuracy: 88.05%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 85.20% | Validation Accuracy: 89.07%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 86.31% | Validation Accuracy: 89.80%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 87.45% | Validation Accuracy: 90.48%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 88.05% | Validation Accuracy: 91.16%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 88.67% | Validation Accuracy: 91.47%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 89.15% | Validation Accuracy: 91.86%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 89.66% | Validation Accuracy: 92.20%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 90.04% | Validation Accuracy: 92.53%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 90.44% | Validation Accuracy: 92.77%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 90.65% | Validation Accuracy: 92.99%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 90.84% | Validation Accuracy: 93.07%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 91.30% | Validation Accuracy: 93.37%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 91.67% | Validation Accuracy: 93.52%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 91.81% | Validation Accuracy: 93.63%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 91.88% | Validation Accuracy: 93.58%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 92.22% | Validation Accuracy: 93.92%
#     Fold 1 Best Val Acc: 0.9392
#     Fold 1 Total Training Time: 4.66 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 58.81% | Validation Accuracy: 79.65%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 77.42% | Validation Accuracy: 84.64%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 81.63% | Validation Accuracy: 86.83%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 83.84% | Validation Accuracy: 88.39%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 85.08% | Validation Accuracy: 89.29%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 86.29% | Validation Accuracy: 90.12%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 87.32% | Validation Accuracy: 90.83%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 88.12% | Validation Accuracy: 91.24%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 88.58% | Validation Accuracy: 91.72%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 89.01% | Validation Accuracy: 92.07%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 89.52% | Validation Accuracy: 92.47%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 89.97% | Validation Accuracy: 92.73%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 90.43% | Validation Accuracy: 93.12%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 90.79% | Validation Accuracy: 93.35%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 90.95% | Validation Accuracy: 93.33%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 91.33% | Validation Accuracy: 93.53%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 91.52% | Validation Accuracy: 93.68%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 91.76% | Validation Accuracy: 93.87%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 91.91% | Validation Accuracy: 93.99%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 91.96% | Validation Accuracy: 94.21%
#     Fold 2 Best Val Acc: 0.9421
#     Fold 2 Total Training Time: 4.69 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 58.56% | Validation Accuracy: 80.23%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 77.37% | Validation Accuracy: 85.13%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 81.46% | Validation Accuracy: 87.50%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 83.62% | Validation Accuracy: 88.74%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 85.07% | Validation Accuracy: 89.75%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 86.29% | Validation Accuracy: 90.63%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 87.40% | Validation Accuracy: 91.37%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 87.95% | Validation Accuracy: 91.83%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 88.61% | Validation Accuracy: 92.42%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 89.11% | Validation Accuracy: 92.61%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 89.56% | Validation Accuracy: 93.11%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 89.91% | Validation Accuracy: 93.43%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 90.26% | Validation Accuracy: 93.39%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 90.74% | Validation Accuracy: 93.74%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 90.77% | Validation Accuracy: 93.84%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 91.29% | Validation Accuracy: 94.00%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 91.45% | Validation Accuracy: 94.02%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 91.81% | Validation Accuracy: 94.34%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 92.04% | Validation Accuracy: 94.37%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 92.00% | Validation Accuracy: 94.37%
#     Fold 3 Best Val Acc: 0.9437
#     Fold 3 Total Training Time: 4.70 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 58.66% | Validation Accuracy: 79.64%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 77.45% | Validation Accuracy: 84.47%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 81.34% | Validation Accuracy: 87.31%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 83.39% | Validation Accuracy: 88.85%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 85.03% | Validation Accuracy: 89.83%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 86.43% | Validation Accuracy: 90.63%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 87.24% | Validation Accuracy: 91.43%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 87.95% | Validation Accuracy: 91.41%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 88.36% | Validation Accuracy: 92.18%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 88.98% | Validation Accuracy: 92.53%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 89.42% | Validation Accuracy: 92.79%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 89.96% | Validation Accuracy: 92.99%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 90.31% | Validation Accuracy: 93.27%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 90.71% | Validation Accuracy: 93.48%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 90.92% | Validation Accuracy: 93.47%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 91.12% | Validation Accuracy: 93.67%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 91.39% | Validation Accuracy: 93.77%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 91.65% | Validation Accuracy: 93.73%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 92.01% | Validation Accuracy: 94.17%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 92.24% | Validation Accuracy: 94.20%
#     Fold 4 Best Val Acc: 0.9420
#     Fold 4 Total Training Time: 4.29 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 58.74% | Validation Accuracy: 79.60%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 77.42% | Validation Accuracy: 84.36%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 81.43% | Validation Accuracy: 86.93%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 83.66% | Validation Accuracy: 88.38%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 85.20% | Validation Accuracy: 89.56%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 86.28% | Validation Accuracy: 90.35%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 87.42% | Validation Accuracy: 90.86%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 87.93% | Validation Accuracy: 91.27%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 88.63% | Validation Accuracy: 91.75%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 89.21% | Validation Accuracy: 92.09%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 89.57% | Validation Accuracy: 92.55%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 89.85% | Validation Accuracy: 92.58%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 90.24% | Validation Accuracy: 92.74%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 90.67% | Validation Accuracy: 92.93%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 91.02% | Validation Accuracy: 93.28%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 91.22% | Validation Accuracy: 93.46%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 91.56% | Validation Accuracy: 93.65%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 91.84% | Validation Accuracy: 93.79%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 91.93% | Validation Accuracy: 93.92%
# Fold 5/5 Epoch 20/20 | Training Accuracy: 92.22% | Validation Accuracy: 94.05%
#     Fold 5 Best Val Acc: 0.9405
#     Fold 5 Total Training Time: 3.04 mins.
# Testing config 4/4: {'lr': 0.001, 'betas': (0.8, 0.999), 'weight_decay': 0.01}
# Fold 1/5 Epoch 1/20 | Training Accuracy: 80.39% | Validation Accuracy: 89.36%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 87.46% | Validation Accuracy: 90.94%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 88.80% | Validation Accuracy: 91.84%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 89.08% | Validation Accuracy: 92.28%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 89.27% | Validation Accuracy: 92.27%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 89.55% | Validation Accuracy: 91.87%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 89.74% | Validation Accuracy: 91.81%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 89.71% | Validation Accuracy: 92.88%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 89.60% | Validation Accuracy: 92.53%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 89.77% | Validation Accuracy: 92.79%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 89.85% | Validation Accuracy: 92.88%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 89.89% | Validation Accuracy: 92.57%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 89.95% | Validation Accuracy: 92.67%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 89.91% | Validation Accuracy: 92.73%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 89.78% | Validation Accuracy: 92.69%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 89.89% | Validation Accuracy: 92.67%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 89.84% | Validation Accuracy: 92.52%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 89.88% | Validation Accuracy: 92.24%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 89.75% | Validation Accuracy: 92.53%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 89.75% | Validation Accuracy: 92.06%
#     Fold 1 Best Val Acc: 0.9288
#     Fold 1 Total Training Time: 3.00 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 80.51% | Validation Accuracy: 89.68%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 87.54% | Validation Accuracy: 91.30%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 88.74% | Validation Accuracy: 92.05%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 88.92% | Validation Accuracy: 92.45%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 89.29% | Validation Accuracy: 92.62%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 89.19% | Validation Accuracy: 93.03%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 89.58% | Validation Accuracy: 92.38%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 89.64% | Validation Accuracy: 92.95%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 89.51% | Validation Accuracy: 92.81%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 89.60% | Validation Accuracy: 92.59%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 89.90% | Validation Accuracy: 93.04%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 89.70% | Validation Accuracy: 93.02%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 89.60% | Validation Accuracy: 93.09%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 89.88% | Validation Accuracy: 92.91%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 89.65% | Validation Accuracy: 92.73%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 89.94% | Validation Accuracy: 93.17%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 89.64% | Validation Accuracy: 92.24%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 89.76% | Validation Accuracy: 92.41%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 89.50% | Validation Accuracy: 93.08%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 89.85% | Validation Accuracy: 92.79%
#     Fold 2 Best Val Acc: 0.9317
#     Fold 2 Total Training Time: 2.99 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 80.22% | Validation Accuracy: 90.09%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 87.56% | Validation Accuracy: 91.39%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 88.69% | Validation Accuracy: 92.43%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 89.24% | Validation Accuracy: 92.69%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 89.38% | Validation Accuracy: 92.80%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 89.50% | Validation Accuracy: 93.64%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 89.69% | Validation Accuracy: 93.09%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 89.55% | Validation Accuracy: 93.08%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 89.51% | Validation Accuracy: 93.49%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 89.64% | Validation Accuracy: 93.13%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 89.53% | Validation Accuracy: 93.27%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 89.80% | Validation Accuracy: 93.67%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 89.69% | Validation Accuracy: 93.55%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 89.66% | Validation Accuracy: 93.59%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 89.77% | Validation Accuracy: 93.23%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 89.53% | Validation Accuracy: 93.36%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 89.75% | Validation Accuracy: 92.93%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 89.87% | Validation Accuracy: 93.67%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 89.78% | Validation Accuracy: 93.41%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 89.68% | Validation Accuracy: 93.45%
#     Fold 3 Best Val Acc: 0.9367
#     Fold 3 Total Training Time: 2.99 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 80.34% | Validation Accuracy: 90.31%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 87.25% | Validation Accuracy: 91.47%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 88.50% | Validation Accuracy: 92.53%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 89.11% | Validation Accuracy: 92.38%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 89.33% | Validation Accuracy: 93.24%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 89.53% | Validation Accuracy: 93.00%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 89.46% | Validation Accuracy: 92.89%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 89.63% | Validation Accuracy: 92.51%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 89.39% | Validation Accuracy: 93.03%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 89.49% | Validation Accuracy: 93.21%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 89.56% | Validation Accuracy: 93.30%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 89.66% | Validation Accuracy: 92.97%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 89.70% | Validation Accuracy: 93.42%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 89.74% | Validation Accuracy: 93.63%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 89.51% | Validation Accuracy: 93.29%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 89.78% | Validation Accuracy: 93.17%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 89.60% | Validation Accuracy: 92.79%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 89.64% | Validation Accuracy: 93.04%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 89.75% | Validation Accuracy: 93.16%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 89.97% | Validation Accuracy: 93.20%
#     Fold 4 Best Val Acc: 0.9363
#     Fold 4 Total Training Time: 2.99 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 80.30% | Validation Accuracy: 90.21%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 87.44% | Validation Accuracy: 92.07%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 88.75% | Validation Accuracy: 92.05%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 89.14% | Validation Accuracy: 92.08%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 89.37% | Validation Accuracy: 92.56%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 89.44% | Validation Accuracy: 92.77%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 89.65% | Validation Accuracy: 92.93%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 89.71% | Validation Accuracy: 93.13%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 89.58% | Validation Accuracy: 93.22%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 89.68% | Validation Accuracy: 92.67%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 89.86% | Validation Accuracy: 92.86%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 89.71% | Validation Accuracy: 92.61%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 89.55% | Validation Accuracy: 92.86%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 89.72% | Validation Accuracy: 92.91%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 89.80% | Validation Accuracy: 93.04%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 89.74% | Validation Accuracy: 92.89%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 89.86% | Validation Accuracy: 93.23%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 89.73% | Validation Accuracy: 92.51%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 89.71% | Validation Accuracy: 92.75%
# Fold 5/5 Epoch 20/20 | Training Accuracy: 89.87% | Validation Accuracy: 93.03%
#     Fold 5 Best Val Acc: 0.9323
#     Fold 5 Total Training Time: 2.99 mins.
# Best configuration: {'lr': 0.001, 'betas': (0.9, 0.999), 'weight_decay': 0.0001}
# Mean Validation Accuracy: 0.9561

# %% [markdown]
# # Branch TODO 3
# Modify the code below to suit the selected optimizer (Adam, RMSProp, AdamW).
# This code should already retrieve the best configurations tested in TODO 2, but please double check that this is the case.
# Adjust other parameters such as the TARGET_ACC as needed; it's currently set to 0.6 for testing purposes.

# %%
# Final training with best configurations using full training set

# Refresh seeding and model.
torch.manual_seed(MANUAL_SEED)
final_model = FeedForwardNet().to(device)

# Using Adam again for example case
final_optimizer = torch.optim.Adam(final_model.parameters(), **best_config_params)
loss_function = torch.nn.CrossEntropyLoss()

# Use all of the training dataset + the held-out test set
full_train_loader = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
testloader = DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False)

# 5.4 & 6.2 Req: Track losses and accuracies
train_losses = []
train_accuracies  = []
test_losses = []
test_accuracies = []

# To check convergence speed
convergence_epoch = None

# This ensures time will be synchronized, does not affect GPU performance.
if device.type == "cuda":
    torch.cuda.synchronize()

# Log start time
start_time = time.perf_counter()

for epoch in range(EPOCHS):
    train_loss, train_acc = run_epoch(
        final_model, full_train_loader, loss_function, final_optimizer, device, training=True
    )

    # 5.3 Req: Evaluate the final trained model exactly once on the held-out test data
    test_loss, test_acc = run_epoch(
        final_model, testloader, loss_function, optimizer=None, device=device, training=False
    )

    # Store metrics for plotting later
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies.append(test_acc)
    
    # Req 5.4: Identify Convergence Epoch
    if test_acc >= TARGET_ACC and convergence_epoch is None:
        convergence_epoch = epoch + 1  # 0-index
        
    print(f"Epoch {epoch + 1}/{EPOCHS}")
    print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
    print(f"Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.4f}")

# Stop time
if device.type == "cuda":
    torch.cuda.synchronize()
end_time = time.perf_counter()

# 5.4 Req: Training Time
total_training_time = end_time - start_time

# 5.4 Req: Final Training and Testing Losses
final_train_acc = train_accuracies[-1]
final_test_acc = test_accuracies[-1]

# 5.4 Req: Final Training and Testing Accuracies
final_train_loss = train_losses[-1]
final_test_loss = test_losses[-1]

# If the model never reached the target threshold, default to the max epochs run
if convergence_epoch is None:
    convergence_epoch = EPOCHS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # Final training with best configurations using full training set
#       2
#       3 # Refresh seeding and model.
# ----> 4 torch.manual_seed(MANUAL_SEED)
#       5 final_model = FeedForwardNet().to(device)
#       6
#       7 # Using Adam again for example case
#
# NameError: name 'torch' is not defined

# %% [markdown]
# # 6. Results
# ### 6.1  Summary Table
# Present a table comparing the best configuration of each optimizer across all metrics defined in Section 5.4. Include both default and best configurations for each optimizer.
#
# ### 6.2  Required Plots
# - Training and validation loss curves over epochs for the best configuration of each optimizer
# (all three on one plot for direct comparison).
# - Training and validation accuracy curves over epochs.
# - Bar chart comparing final test accuracy across optimizers.
# - Box plot or error-bar plot showing the cross-validation accuracy distribution for each optimizer.
# - Optional: learning-rate sensitivity plot showing validation accuracy vs. learning rate for each optimizer.
#
# ### 6.3  Reproducibility
# - State the random seed used.
# - Specify library versions (Python, PyTorch, torchvision).
# - Confirm that results in the report can be reproduced by running the submitted code with no
# modifications.

# %%
# 6.1 Requirement Placeholder
# Sample Metric Report (for now)
print("\n" + "="*40)
print("FINAL PRODUCTION RUN METRICS LOG")
print("="*40)
print(f"1. Training Accuracy (Final Epoch): {final_train_acc * 100:.2f}%")
print(f"2. Cross-Validation Accuracy: Mean: {best_config_data[0]:.4f}; Standard Dev: {best_config_data[1]:.4f}")
print(f"3. Test Accuracy: {final_test_acc * 100:.2f}%")
print(f"4. Final Loss:")
print(f"   - Final Training Loss:{final_train_loss:.4f}")
print(f"   - Final Test Loss: {final_test_loss:.4f}")
print(f"5. Convergence Speed: {convergence_epoch} epochs to reach {TARGET_ACC * 100:.0f}% train accuracy")
print(f"6. Total Training Time: {total_training_time:.2f} seconds")
print("="*40)
# Out:
# ========================================
# FINAL PRODUCTION RUN METRICS LOG
# ========================================
# 1. Training Accuracy (Final Epoch): 95.09%
# 2. Cross-Validation Accuracy: Mean: 0.9561; Standard Dev: 0.0018
# 3. Test Accuracy: 89.61%
# 4. Final Loss:
#    - Final Training Loss:0.1479
#    - Final Test Loss: 0.3697
# 5. Convergence Speed: 1 epochs to reach 60% train accuracy
# 6. Total Training Time: 420.15 seconds
# ========================================

# %% [markdown]
# ### Final Report TODO:
# Based on the requirements mentioned in 6.2, we will need to include all three optimizers in the same notebook. Otherwise, we won't be able to compare them side by side in these plots.

# %% [markdown]
# # Branch TODO 4
# Use the following graph templates to visualize the results for your optimizer.
# Notice that the architecture assumes all three optimizers will be compared in some of the graphs; in this case, double check that the information being populated for the y axis is in the correct order. Currently the placeholder code assumes Adam in index 0.

# %%
# 6.2: Training and validation loss curves over epochs for the best configuration of each optimizer 
# (all three on one plot for direct comparison).
x = range(EPOCHS)
plt.figure(figsize=(12, 8))
plt.plot(x, train_losses, marker='x', color='g', label='Train Loss')
plt.plot(x, test_losses, marker='o', color='b', label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Cross Entropy Loss')
plt.title('Train & Test Loss over Epochs')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # 6.2: Training and validation loss curves over epochs for the best configuration of each optimizer
#       2 # (all three on one plot for direct comparison).
# ----> 3 x = range(EPOCHS)
#       4 plt.figure(figsize=(12, 8))
#       5 plt.plot(x, train_losses, marker='x', color='g', label='Train Loss')
#       6 plt.plot(x, test_losses, marker='o', color='b', label='Test Loss')
#
# NameError: name 'EPOCHS' is not defined

# %%
# 6.2: Training and validation accuracy curves over epochs.
x = range(EPOCHS)
plt.figure(figsize=(12, 8))
plt.plot(x, train_accuracies, marker='x', color='g', label='Train Accuracy')
plt.plot(x, test_accuracies, marker='o', color='b', label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Train & Test Accuracies over Epochs')
plt.legend()
plt.show()

# %%
# 6.2: Bar chart comparing final test accuracy across optimizers.
# Placeholder code for now. Will add all optimizers later.
x = ['Adam', 'RMSProp', 'AdamW']
y = [final_test_acc, TARGET_ACC, TARGET_ACC]
plt.figure(figsize=(12, 8))
plt.bar(x, y)
plt.xlabel('Optimizers')
plt.ylabel('Accuracy')
plt.title('Final Accuracy by Optimizer')
plt.show()

# %%
# 6.2: Box plot or error-bar plot showing the cross-validation accuracy distribution for each optimizer.
# Use Error Bar Plot since we only have mean and standard deviations

# Placeholder code for now; will update with all optimizers later.
means = [best_config_data[0], 0.5, 0.8]
stddevs = [best_config_data[1], 0.1, 0.05]

# Define size
plt.figure(figsize=(12, 8))

# Plot the error bar
plt.errorbar(x=x, y=means, yerr=stddevs, fmt='o', color='green', ecolor='red', label= 'CV Accuracy (Mean ± SD)')
plt.title('Cross Validation Accuracy Distribution by Optimizer')
plt.xlabel('Optimizer')
plt.ylabel('Validation Accuracy')

# %%
# 6.2: Optional: learning-rate sensitivity plot showing validation accuracy vs. learning rate for each optimizer.

# %%
# 6.3 Reproducibility
# Final Report TODO: Will add later.

# %% [markdown]
# # 7. Interpretation and Discussion
# ### 7.1  Optimizer Analysis
# - Describe the convergence behaviour of each optimizer. Which converged fastest? Which was
# most stable?
# - Discuss  how  each  optimizer  responded  to  learning  rate  changes.  Was  any  optimizer
# particularly sensitive or robust?
# - Compare the generalization gap (train accuracy vs. test accuracy) across optimizers. What
# might explain the differences?
#
# ### 7.2  Weight Decay and Regularization
# - Explain,  with  reference  to  your  results,  how  decoupled  weight  decay  in  AdamW  affects
# generalization compared with Adam.
# - If AdamW did not outperform Adam in your experiment, provide a hypothesis for why.
#
# ### 7.3  Conclusion and Recommendation
# - State clearly which optimizer performed best on KMNIST and why.
# - Suggest when you would choose each optimizer in a real-world scenario, beyond this specific
# task.
# - Identify at least two limitations of your experimental design and suggest how future work could address them.

# %% [markdown]
# # Branch TODO 5
# For each of the sections below, conduct analyses based solely on the optimizer chosen first. Ignore the comparisons for now; for instance, just describe the convergence behavior of the selected optimizer (e.g., RMSProp) on its own while including empirical values; these values will be helpful later as we synthesize the findings for the comparison.

# %% [markdown]
# ### Note on β1 Investigation
#
# This notebook tests the same configurations as baseline_model_gpu.ipynb but with
# explicit β1 values. The results were identical to the default settings (β1=0.9),
# confirming that specifying β1=0.9 explicitly produces the same outcome as using
# the PyTorch default. The full analysis is documented in baseline_model_gpu.ipynb.

# %%
# 7.1 Optimizer Analysis (Single Focus)
# Add information about the convergence behavior of the single optimizer
# Add information about how the optimizer responded to learning rate changes
# Add information about the generalization gap within the single optimizer.

# %%
# 7.2 Weight Decay & Regularization (Not Applicable)

# %%
# 7.3 Conclusion & Recommendation
# Add information about when the optimizer might be chosen for a real-world scenario.
# Identify one limitation in the experimental design with respect to the optimizer
# Suggest how future work may address the limitation.
