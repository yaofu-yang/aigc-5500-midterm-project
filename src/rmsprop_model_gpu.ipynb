# %% [markdown]
# # Midterm Project
# - AIGC 5500 0NA
# - Advanced Deep Learning
# - Summer 2026
#
#
# ### Team Info
# HawkAI Detection | Group 1
# | Name | Github |
# | --- | --- |
# | Kevin Joseff Cabrera (Kevin) | https://github.com/kjcabPL |
# | Mohd Mujtaba Saighani (Mujtaba) | https://github.com/saigha1 |
# | Thiago Segantini Nogeuira (Thiago) | https://github.com/thiaseg |
# | Sayamon Sittiprom (Saya) | https://github.com/sittiprom |
# | Yao-Fu Yang (Andy) | https://github.com/yaofu-yang |

# %% [markdown]
# ### 1. Overview (Project Instructions)
# In the activation functions and gradient descent module, you studied variations of gradient descent
# and the hyperparameters that govern training dynamics. This project puts that knowledge to work:
# you will systematically compare three modern optimizers on a real image-classification task, analyze
# how each one behaves under different hyperparameter settings, and communicate your findings in a
# live group presentation.
# - Objective: Implement, tune, and compare Adam, RMSprop, and AdamW on a feedforward
# neural network trained on the KMNIST dataset, and draw evidence-based conclusions about
# their relative strengths and trade-offs.
# - Importance: Choosing the wrong optimizer or leaving hyperparameters at default values is
# one of the most common causes of poor model performance. This project builds the analytical
# habits you will carry into every future deep learning task.

# %% [markdown]
# ### 2. Dataset (Project Instructions)
# Use the KMNIST (Kuzushiji-MNIST) dataset, available directly through PyTorch:
# | Property | Details |
# |---|---|
# |Training Samples| 60,000 Images|
# |Test Samples| 10,000 Images|
# |Image Size | 28 x 28 Pixels, Greyscale|
# |Classes| 10 (Japanese Hiragana Characters)|
# |Complexity| Higher than MNIST; class boundaries overlap|

# %%
# Handle all imports first
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms

# Kuzushiji-MNIST Dataset
from torchvision.datasets import KMNIST
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import KFold
from typing import Type, Dict, Any, Callable
import numpy as np
from matplotlib import pyplot as plt
import time

# %%
# Define data preparation constants
MANUAL_SEED = 498
ROOT ='./kuzushiji_data'

# %%
# Load the data and complete basic exploration

# Setting the random seed
torch.manual_seed(MANUAL_SEED)

# Use GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load Training data as a single batch to compute mean and standard deviation
# Define a transformation to Tensor
transform = transforms.Compose([transforms.ToTensor()])
trainset = KMNIST(root=ROOT, train=True, download=True, transform=transform)
trainloader = DataLoader(trainset, batch_size=len(trainset), shuffle=True)
data = next(iter(trainloader))
mean = data[0].mean().item()
stddev = data[0].std().item()
print(f"The mean is : {mean}")
print(f"The standard deviation is: {stddev}")
# Out:
# Using device: cuda
# The mean is : 0.19176216423511505
# The standard deviation is: 0.3483428359031677

# %%
# Check data shape
# (Batch Size, Channel Counts, Row Pixels, Column Pixels)
data[0].size()
# Out:
# torch.Size([60000, 1, 28, 28])

# %%
# Prepare the data

# Apply Input Standardization to reduce risk of saturating neurons
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize([mean], [stddev])])

# Create training and testing sets while applying standardization
trainset = KMNIST(root=ROOT, train=True, download=True, transform=transform)
testset = KMNIST(root=ROOT, train=False, download=True, transform=transform)


# Verify final dimension of all three data sets
print(f"Train set size: {len(trainset)}")
print(f"Test set size: {len(testset)}")
# Out:
# Train set size: 60000
# Test set size: 10000

# %% [markdown]
# # 3. Model Architecture (Project Instructions)
# Implement the following feedforward fully-connected architecture. Do not modify it; the architecture is fixed so that all differences between runs are attributable to the optimizer and its hyperparameters.
#
# |Layer|Configuration|Notes
# |---|---|---|
# |Input|784 Neurons|Flatten 28x28 image|
# |Hidden 1|128 Neurons, ReLU Activation||
# |Hidden 1|64 Neurons, ReLU Activation||
# |Output|10 Neurons, Softmax activation|One neuron per class|
# |Loss function|Cross-Entropy Loss|Appropriate for multi-class classification|

# %%
# Define architectural constants
INPUT_DIM = 784  # Cannot change
HIDDEN_DIM1 = 128  # Cannot change
HIDDEN_DIM2 = 64  # Cannot change
OUTPUT_DIM = 10  # Cannot change

# %%
# Define the forward pass. Final activation is omitted since softmax is part of
# cross-entropy loss function in PyTorch.
class FeedForwardNet(nn.Module):
    def __init__(
        self,
        input_dim:  int = INPUT_DIM,
        hidden_dim1: int = HIDDEN_DIM1,
        hidden_dim2: int = HIDDEN_DIM2,
        output_dim: int = OUTPUT_DIM
    ) -> None:
        super().__init__()
        # First Hidden Layer
        self.hidden1 = nn.Linear(input_dim, hidden_dim1)
        # Apply BatchNorm to first hidden layer
        self.batchNorm1 = nn.BatchNorm1d(num_features=hidden_dim1)
        # Apply random deactivation of neurons to reduce overfitting
        self.dropout1 = nn.Dropout(p=0.2)

        # Second Hidden Layer
        self.hidden2 = nn.Linear(hidden_dim1, hidden_dim2)
        # Apply BatchNorm to second hidden layer
        self.batchNorm2 = nn.BatchNorm1d(num_features=hidden_dim2)
        # Apply random deactivation of neurons to reduce overfitting
        self.dropout2 = nn.Dropout(p=0.2)

        # Final Output Layer
        self.output = nn.Linear(hidden_dim2, output_dim)

        # Customized function to initialize weights for each layer.
        self._initialize_weights()

    # Applies Weight Initialization technique.
    def _initialize_weights(self) -> None:
        # Kaiming (He) initialization for first hidden layer
        nn.init.kaiming_normal_(self.hidden1.weight, nonlinearity='relu')
        nn.init.constant_(self.hidden1.bias, 0.0)

        # Same for second hidden layer
        nn.init.kaiming_normal_(self.hidden2.weight, nonlinearity='relu')
        nn.init.constant_(self.hidden2.bias, 0.0)

        # Xavier (Glorot) initialization for the output layer (no activation).
        nn.init.xavier_uniform_(self.output.weight)
        nn.init.constant_(self.output.bias, 0.0)

    # Completes the forward pass
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # Flatten the image from 28x28 to 784 pixels
        x = torch.flatten(x, start_dim=1)

        # First layers (hidden, batchnorm, relu activation, dropout)
        x = self.hidden1(x)
        x = self.batchNorm1(x)
        x = F.relu(x)
        x = self.dropout1(x)

        # Second Layers (hidden, batchnorm, relu activation, dropout)
        x = self.hidden2(x)
        x = self.batchNorm2(x)
        x = F.relu(x)
        x = self.dropout2(x)

        return self.output(x)    # Raw logits; softmax applied by loss function.

# Initializes the model.
model = FeedForwardNet()

# %% [markdown]
# # 4. Optimizers Under Investigation (Project Instructions)
# You will train and evaluate the same fixed architecture using each of the three optimizers below. For
# every optimizer, perform a structured hyperparameter search (see Section 5) and report results for
# both the default configuration and the best configuration found.
#
# ### 4.1  Adam (Adaptive Moment Estimation)
# - Key idea: Maintains separate adaptive learning rates for each parameter by combining first-
# moment (momentum) and second-moment (uncentred variance) estimates.
# - Default settings: lr = 0.001, β1 = 0.9, β2 = 0.999, ε = 1e-8.
# - Investigate: The effect of learning rate and β1 on convergence speed and final accuracy.
#
# ### 4.2  RMSprop (Root Mean Square Propagation)
# - Key idea: Divides the learning rate by a running average of the squared gradient magnitudes,
# preventing updates from growing too large.
# - Default settings: lr = 0.01, α = 0.99, ε = 1e-8.
# - Investigate: The effect of the decay factor α and learning rate on training stability.
#
# ### 4.3  AdamW (Adam with Decoupled Weight Decay)
# - Key  idea:  Corrects a known flaw in Adam’s L2 regularization by decoupling weight decay
# from the adaptive learning-rate update, leading to better generalization.
# - Default settings: lr = 0.001, β1 = 0.9, β2 = 0.999, ε = 1e-8, weight_decay = 0.01.
# - Investigate: The effect of weight_decay and learning rate on the gap between training and
# test accuracy.

# %% [markdown]
# ### Branch TODO 1: Research the Assigned Optimizer
# The project instructions give a brief overview of the key ideas, default settings, and investigation pathways for each optimizer. Start by completing the investigation tasks but go deeper to find other intereting and unique parameters/features of each optimizer (including ones not covered in lecture).
#
# Action Item: Add a document in the branch with the findings, or include the findings directly in the notebook. For reference, the final PDF report requires the following: "Optimizer descriptions and theoretical background"

# %%
# Define adjustable constants
EPOCHS = 20 # Min 20
BATCH_SIZE = 64  # May change
K_FOLD = 5 # Cannot change
TARGET_ACC = 0.6 # Will change

# %% [markdown]
# # Methodology (Project Instructions)
# ### 5.1  Hyperparameter Search
# For each optimizer, evaluate at least four (4) distinct hyperparameter configurations. You may use
# grid search, random search, or a manual systematic approach. Document your search strategy and
# justify your final selection.
#
# At minimum, vary the following for each optimizer:
# - Learning  rate: try values  spanning  at  least  two  orders  of magnitude (e.g.,  0.1,  0.01,  0.001,
# 0.0001).
# - At least one optimizer-specific hyperparameter (e.g., β1 for Adam/AdamW, decay factor for
# RMSprop).
#
# ### 5.2  Cross-Validation
# - Apply 5-fold cross-validation on the training set to estimate generalization performance.
# - Report  the  mean  and  standard  deviation  of  validation  accuracy  across  folds  for  each
# configuration.
# - Use the best configuration identified through cross-validation to train a final model on the full
# training set.
#
# ### 5.3  Training Protocol
# - Train  for  a  fixed  number  of  epochs  (minimum  20)  across  all  configurations  to  ensure  fair
# comparison.
# - Use the same random seed for all runs to control for initialization variance.
# - Record training loss, validation loss, and validation accuracy at each epoch.
# - Evaluate the final model on the held-out test set; report test accuracy and test loss.
#
# ### 5.4  Metrics to Record
# |Metric|Description|
# |---|---|
# |Training Accuracy|Accuracy on the training set at the final epoch|
# |Validation Accuracy|Mean cross-validation accuracy (and std dev) across 5 folds|
# |Test Accuracy|Accuracy on the held-out test set |
# |Final Loss|Training and test loss at the end of training|
# |Convergence Speed|Number of epochs to reach a target validation accuracy (e.g.,
# 80%)|
# |Training Time|Wall-clock time for a full training run|

# %%
# Define a reusable run Epoch function for both training & evaluation loops
def run_epoch(
    model:     nn.Module,
    loader:    DataLoader,
    criterion: nn.Module,
    optimizer: torch.optim.Optimizer | None,
    device:    torch.device,
    training:  bool,
) -> tuple[float, float]:
    """Run one full pass over the DataLoader.
    Pass optimizer=None during evaluation.
    Returns (mean loss, accuracy).
    """
    model.train() if training else model.eval()

    total_loss    = 0.0
    total_correct = 0
    total_samples = 0

    # No gradient/back propagation if in evaluation mode.
    context = torch.enable_grad() if training else torch.no_grad()

    with context:
        for inputs, targets in loader:
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = model(inputs)
            # Cross-entropy loss does not need one-hot targets in PyTorch.
            loss = criterion(outputs, targets)

            # Only run for training mode. Evaluation mode skips this.
            if training:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            # Accumulate metrics.
            _, predicted   = torch.max(outputs, dim=1)
            total_correct += (predicted == targets).sum().item()
            total_samples += targets.size(0)
            total_loss    += loss.item()

    return total_loss / len(loader), total_correct / total_samples

# %%
# Define a reusable k-fold cross-validation function for different optimizers
# Handles the requirements in 5.2 Cross Validation & 5.3 Training Protocol

def cross_validate_config(
    model_class: Callable[[], nn.Module],  # Need a fresh model for each fold
    train_dataset: Any,
    optimizer_class: Type[torch.optim.Optimizer],  # Type of optimizer
    optimizer_kwargs: Dict[str, Any],  # Hyperparameters
    criterion: nn.Module,
    device: torch.device,
    epochs: int = EPOCHS,  # 5.3 Req, min 20 Epochs
    batch_size: int = BATCH_SIZE,
    n_splits: int = K_FOLD,  # 5.2 Req: 5-fold
    random_seed: int = MANUAL_SEED,

) -> tuple[float, float]:
    """
    Performs K-Fold Cross-Validation for a given model, optimizer,
    and hyperparameter configuration.

    Returns:
        tuple: (
            mean_accuracy,       # mean validation accuracy across folds
            std_accuracy,        # std dev of validation accuracy across folds
            fold0_train_losses,  # per-epoch train losses (fold 1 only, for plotting)
            fold0_val_losses,    # per-epoch val losses (fold 1 only, for plotting)
        )
    """
    k_fold = KFold(n_splits=n_splits, shuffle=True, random_state=random_seed)
    fold0_train_losses, fold0_val_losses = [], []
    fold_best_accuracies = []
    fold_train_times = []
    total_train_time = 0
    start_train_time = time.perf_counter()
    
    for fold, (train_idx, val_idx) in enumerate(k_fold.split(train_dataset)):
        # 5.3 Req: Use the same random seed for all runs to control for initialization variance.
        torch.manual_seed(random_seed)

        # Add time recording for each training fold
        fold_start_time = time.perf_counter()
        
        # Move model to device
        model = model_class().to(device)
        
        # Create optimizer using the class and parameter arguments
        optimizer = optimizer_class(model.parameters(), **optimizer_kwargs)
        
        # Generate the training folds and validation fold
        train_sub = Subset(train_dataset, train_idx)
        val_sub   = Subset(train_dataset, val_idx)
        
        # Generate the training and validation loaders
        trainloader = DataLoader(train_sub, batch_size=batch_size, shuffle=True)
        valloader   = DataLoader(val_sub, batch_size=batch_size, shuffle=False)
        
        # For tracking accuracy
        best_fold_val_acc = 0.0
        
        # Complete the training and validation per Epoch and capture metrics
        for epoch in range(epochs):
            # Training loop with the training loss and training accuracy
            train_loss, train_acc = run_epoch(
                model, trainloader, criterion, optimizer, device, training=True
            )

            # Validation loop with the validation loss and validation accuracy
            # No optimizers needed for validation, training pathway should not be run
            val_loss, val_acc = run_epoch(
                model, valloader, criterion, optimizer=None, device=device, training=False
            )
            
            # Update the best validation accuracy
            if val_acc > best_fold_val_acc:
                best_fold_val_acc = val_acc

            if fold == 0:
                fold0_train_losses.append(train_loss)
                fold0_val_losses.append(val_loss)    

            # Report Epoch & Losses/Accuracies
            print(f"Fold {fold + 1}/{n_splits} Epoch {epoch + 1}/{epochs} | Training Accuracy: {(train_acc * 100):.2f}% | Validation Accuracy: {(val_acc * 100):.2f}%")

        # Record training time for current fold
        fold_end_time = time.perf_counter()
        fold_train_time = (fold_end_time - fold_start_time) / 60 # Converted to minutes
        
        # Tracking validation accuracies
        fold_best_accuracies.append(best_fold_val_acc)
        fold_train_times.append({
            "fold": fold + 1, 
            "epochs": epochs,
            "time": fold_train_time
        })
        print(f"    Fold {fold + 1} Best Val Acc: {best_fold_val_acc:.4f} ({(best_fold_val_acc * 100):.2f})%")
        print(f"    Fold {fold + 1} Total Training Time: {fold_train_time:.2f} mins.")

    end_train_time = time.perf_counter()
    total_train_time = (end_train_time - start_train_time) / 60 # converted to minutes
    fold_train_times.append({
        "fold": "Total", 
        "epochs": epochs,
        "time": total_train_time
    })
    print(f"    All Folds Completion Total Training Time: {total_train_time:.2f} mins.")
    # Calculate aggregated statistics
    acc_tensor = torch.tensor(fold_best_accuracies)

    # 5.2 Req: report mean and standard deviation of validation accuracies
    # Needed for 6.2 plotting accuracy distribution as well.
    return acc_tensor.mean().item(), acc_tensor.std().item(), fold0_train_losses, fold0_val_losses

# %% [markdown]
# # Branch TODO 2
# Modify the code below for your selected optimizer (Adam, RMSProp, AdamW).
# Make sure to include the hyperparameter changes that were identified in TODO 1/Section 4.
# Consider also changing the architecture to use Optuna or Ray Tune as discussed in lecture.
# The reusable cross-validation function should be compatible with both approaches, but feel free to modify the function with design improvements, etc.

# %% [markdown]
# - Learning  rate: try values  spanning  at  least  two  orders  of magnitude (e.g.,  0.1,  0.01,  0.001,
# 0.0001).

# %%
# Example code for optimizer trials with different hyperparameter configurations

optimizer_name = "RMSprop"
optimizer_class = torch.optim.RMSprop

# Define sample hyperparamters.
# To fulfill requirements, need to have four unique configurations
# hyperparameters = [
#     {"lr" :0.01, "alpha" : 0.99, "eps" :1e-8},
#     {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8, "momentum":  0.9},
#     # {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8, "momentum":  0.001},
#     {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8, "momentum":  0.003},
#     {"lr": 0.01,   "alpha": 0.80, "eps": 1e-8, "momentum":  0.003},
#     {"lr": 0.01,   "alpha": 0.99,  "eps": 1e-07, "momentum":  0.003},
#      {"lr": 0.001,   "alpha": 0.99, "eps": 1e-8, "momentum":  0.003 ,},
#      {"lr": 0.0001,   "alpha": 0.99, "eps": 1e-8, "momentum":  0.003,"weight_decay": 1e-2}
# ]

hyperparameters = [
    {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8},                          
    {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8, "momentum": 0.9},         
    {"lr": 0.01,   "alpha": 0.80, "eps": 1e-8},                          
    {"lr": 0.001,  "alpha": 0.99, "eps": 1e-8},                          
    {"lr": 0.0001, "alpha": 0.99, "eps": 1e-8},                          
    {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8, "weight_decay": 1e-4},    
    {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8, "weight_decay": 1e-3},    
    {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8, "weight_decay": 1e-2},    
    {"lr": 0.01,   "alpha": 0.99,  "eps": 1e-07, "momentum":  0.003},
]



# Will store the results from the best configuration for this optimizer
best_configuration_results = {}

# Define evaluation metrics
best_config_score = -1.0
best_config_data = None
best_config_params = None
loss_histories = {}

# %%
# Example code for optimizer trials with different hyperparameter configurations

optimizer_name = "RMSprop"
optimizer_class = torch.optim.RMSprop

# Define sample hyperparamters.
# To fulfill requirements, need to have four unique configurations
# hyperparameters = [
#     {"lr" :0.01, "alpha" : 0.99, "eps" :1e-8},
#     {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8, "momentum":  0.9},
#     # {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8, "momentum":  0.001},
#     {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8, "momentum":  0.003},
#     {"lr": 0.01,   "alpha": 0.80, "eps": 1e-8, "momentum":  0.003},
#     {"lr": 0.01,   "alpha": 0.99,  "eps": 1e-07, "momentum":  0.003},
#      {"lr": 0.001,   "alpha": 0.99, "eps": 1e-8, "momentum":  0.003 ,},
#      {"lr": 0.0001,   "alpha": 0.99, "eps": 1e-8, "momentum":  0.003,"weight_decay": 1e-2}
# ]

hyperparameters = [
    {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8},                          
    {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8, "momentum": 0.9},         
    {"lr": 0.01,   "alpha": 0.80, "eps": 1e-8},                          
    {"lr": 0.001,  "alpha": 0.99, "eps": 1e-8},                          
    {"lr": 0.0001, "alpha": 0.99, "eps": 1e-8},                          
    {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8, "weight_decay": 1e-4},    
    {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8, "weight_decay": 1e-3},    
    {"lr": 0.01,   "alpha": 0.99, "eps": 1e-8, "weight_decay": 1e-2},    
    {"lr": 0.01,   "alpha": 0.99,  "eps": 1e-07, "momentum":  0.003},
]



# Will store the results from the best configuration for this optimizer
best_configuration_results = {}

# Define evaluation metrics
best_config_score = -1.0
best_config_data = None
best_config_params = None
loss_histories = {} 

for config_idx, config_kwargs in enumerate(hyperparameters):
    # Example: Testing config 1/1: {"lr": 0.1, "weight_decay": 1e-4}
    print(f"Testing config {config_idx + 1}/{len(hyperparameters)}: {config_kwargs}")

    # Invoke the Cross-Validation function defined earlier
    result = cross_validate_config(
        model_class=FeedForwardNet,
        train_dataset=trainset,
        optimizer_class=optimizer_class,
        optimizer_kwargs=config_kwargs,
        criterion=nn.CrossEntropyLoss(),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        device=device
    )

    loss_histories[str(config_kwargs)] = {
    "train": result[2],
    "val": result[3],
}

    # Check and update for best results based on accuracy mean
    if result[0] > best_config_score:
        best_config_score = result[0]
        best_config_data = result
        best_config_params = config_kwargs

# This will be used for plotting later.
best_configuration_results[optimizer_name] = {
    "params": best_config_params,
    "metrics": best_config_data,
}

print(f"Best configuration: {best_config_params}")
print(f"Mean Validation Accuracy: {best_config_score:.4f}")


# Plot 1: Validation loss per config
plt.figure(figsize=(12, 8))
for label, losses in loss_histories.items():
    plt.plot(range(1, len(losses["val"]) + 1), losses["val"], marker='o', label=label)
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title('RMSprop: Validation Loss by Hyperparameter Configuration')
plt.legend()
plt.show()

# Plot 2: Training loss per config 
plt.figure(figsize=(12, 8))
for label, losses in loss_histories.items():
    plt.plot(range(1, len(losses["train"]) + 1), losses["train"], marker='o', label=label)  # <- changed "val" to "train"
plt.xlabel('Epoch')
plt.ylabel('Training Loss')   
plt.title('RMSprop: Training Loss by Hyperparameter Configuration')  
plt.legend()
plt.show()
# Out:
# Testing config 1/9: {'lr': 0.01, 'alpha': 0.99, 'eps': 1e-08}
# Fold 1/5 Epoch 1/20 | Training Accuracy: 84.56% | Validation Accuracy: 91.88%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 90.01% | Validation Accuracy: 93.33%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 91.41% | Validation Accuracy: 93.97%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 92.16% | Validation Accuracy: 94.43%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 92.65% | Validation Accuracy: 94.77%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 93.08% | Validation Accuracy: 94.87%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 93.61% | Validation Accuracy: 94.92%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 93.75% | Validation Accuracy: 95.00%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 94.11% | Validation Accuracy: 94.99%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 94.18% | Validation Accuracy: 94.97%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 94.14% | Validation Accuracy: 94.97%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 94.40% | Validation Accuracy: 95.19%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 94.67% | Validation Accuracy: 95.23%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 94.80% | Validation Accuracy: 95.36%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 94.92% | Validation Accuracy: 95.22%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 95.11% | Validation Accuracy: 95.41%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 95.06% | Validation Accuracy: 95.33%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 95.24% | Validation Accuracy: 95.41%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 95.31% | Validation Accuracy: 95.47%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 95.46% | Validation Accuracy: 95.40%
#     Fold 1 Best Val Acc: 0.9547 (95.47)%
#     Fold 1 Total Training Time: 0.70 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 84.32% | Validation Accuracy: 91.51%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 89.74% | Validation Accuracy: 93.73%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 91.14% | Validation Accuracy: 94.33%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 91.90% | Validation Accuracy: 94.47%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 92.66% | Validation Accuracy: 95.07%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 93.17% | Validation Accuracy: 95.16%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 93.56% | Validation Accuracy: 95.23%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 93.87% | Validation Accuracy: 95.39%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 94.11% | Validation Accuracy: 95.56%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 94.35% | Validation Accuracy: 95.45%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 94.57% | Validation Accuracy: 95.34%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 94.72% | Validation Accuracy: 95.54%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 94.90% | Validation Accuracy: 95.53%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 94.98% | Validation Accuracy: 95.62%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 95.04% | Validation Accuracy: 95.77%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 95.08% | Validation Accuracy: 95.64%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 95.23% | Validation Accuracy: 95.78%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 95.33% | Validation Accuracy: 95.74%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 95.54% | Validation Accuracy: 95.74%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 95.55% | Validation Accuracy: 95.75%
#     Fold 2 Best Val Acc: 0.9578 (95.78)%
#     Fold 2 Total Training Time: 0.69 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 84.23% | Validation Accuracy: 92.72%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 89.83% | Validation Accuracy: 93.85%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 91.39% | Validation Accuracy: 94.78%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 92.25% | Validation Accuracy: 94.87%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 92.51% | Validation Accuracy: 95.11%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 93.04% | Validation Accuracy: 95.39%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 93.41% | Validation Accuracy: 95.35%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 93.76% | Validation Accuracy: 95.19%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 93.84% | Validation Accuracy: 95.67%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 94.09% | Validation Accuracy: 95.42%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 94.33% | Validation Accuracy: 95.72%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 94.58% | Validation Accuracy: 95.86%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 94.73% | Validation Accuracy: 95.93%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 94.78% | Validation Accuracy: 95.76%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 95.05% | Validation Accuracy: 95.80%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 95.10% | Validation Accuracy: 95.91%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 95.04% | Validation Accuracy: 96.06%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 95.18% | Validation Accuracy: 95.82%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 95.34% | Validation Accuracy: 95.83%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 95.51% | Validation Accuracy: 95.75%
#     Fold 3 Best Val Acc: 0.9606 (96.06)%
#     Fold 3 Total Training Time: 0.68 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 84.16% | Validation Accuracy: 91.97%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 89.50% | Validation Accuracy: 93.94%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 91.23% | Validation Accuracy: 94.15%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 92.06% | Validation Accuracy: 94.45%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 92.76% | Validation Accuracy: 94.81%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 93.14% | Validation Accuracy: 95.28%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 93.39% | Validation Accuracy: 94.97%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 93.79% | Validation Accuracy: 95.22%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 93.87% | Validation Accuracy: 95.25%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 94.31% | Validation Accuracy: 95.37%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 94.35% | Validation Accuracy: 95.27%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 94.50% | Validation Accuracy: 95.38%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 94.61% | Validation Accuracy: 95.62%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 94.75% | Validation Accuracy: 95.58%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 94.82% | Validation Accuracy: 95.47%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 95.00% | Validation Accuracy: 95.68%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 95.09% | Validation Accuracy: 95.47%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 95.35% | Validation Accuracy: 95.57%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 95.21% | Validation Accuracy: 95.84%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 95.54% | Validation Accuracy: 95.23%
#     Fold 4 Best Val Acc: 0.9584 (95.84)%
#     Fold 4 Total Training Time: 0.68 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 84.51% | Validation Accuracy: 92.30%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 89.84% | Validation Accuracy: 93.23%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 91.29% | Validation Accuracy: 94.23%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 92.06% | Validation Accuracy: 94.57%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 92.61% | Validation Accuracy: 94.67%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 93.22% | Validation Accuracy: 94.92%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 93.64% | Validation Accuracy: 95.12%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 93.84% | Validation Accuracy: 95.15%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 93.90% | Validation Accuracy: 95.24%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 94.19% | Validation Accuracy: 95.28%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 94.46% | Validation Accuracy: 95.28%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 94.46% | Validation Accuracy: 95.44%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 94.69% | Validation Accuracy: 95.13%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 95.04% | Validation Accuracy: 95.06%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 94.94% | Validation Accuracy: 95.03%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 95.17% | Validation Accuracy: 95.43%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 95.24% | Validation Accuracy: 95.43%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 95.37% | Validation Accuracy: 95.37%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 95.38% | Validation Accuracy: 95.64%
# Fold 5/5 Epoch 20/20 | Training Accuracy: 95.51% | Validation Accuracy: 95.79%
#     Fold 5 Best Val Acc: 0.9579 (95.79)%
#     Fold 5 Total Training Time: 0.67 mins.
# Testing config 2/9: {'lr': 0.01, 'alpha': 0.99, 'eps': 1e-08, 'momentum': 0.9}
# Fold 1/5 Epoch 1/20 | Training Accuracy: 73.05% | Validation Accuracy: 87.73%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 81.84% | Validation Accuracy: 88.72%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 84.21% | Validation Accuracy: 90.00%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 85.66% | Validation Accuracy: 90.73%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 86.23% | Validation Accuracy: 92.01%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 87.23% | Validation Accuracy: 91.89%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 87.25% | Validation Accuracy: 92.34%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 87.89% | Validation Accuracy: 91.77%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 88.54% | Validation Accuracy: 92.27%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 88.51% | Validation Accuracy: 92.32%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 88.72% | Validation Accuracy: 92.70%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 89.01% | Validation Accuracy: 92.93%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 88.99% | Validation Accuracy: 93.12%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 89.35% | Validation Accuracy: 93.05%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 89.57% | Validation Accuracy: 92.71%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 89.86% | Validation Accuracy: 93.49%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 89.72% | Validation Accuracy: 92.95%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 89.91% | Validation Accuracy: 92.93%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 89.80% | Validation Accuracy: 92.12%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 90.08% | Validation Accuracy: 93.20%
#     Fold 1 Best Val Acc: 0.9349 (93.49)%
#     Fold 1 Total Training Time: 0.68 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 73.27% | Validation Accuracy: 86.22%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 82.14% | Validation Accuracy: 89.65%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 84.19% | Validation Accuracy: 90.96%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 85.20% | Validation Accuracy: 90.76%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 85.89% | Validation Accuracy: 91.62%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 86.29% | Validation Accuracy: 91.75%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 87.04% | Validation Accuracy: 92.23%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 87.06% | Validation Accuracy: 90.82%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 87.62% | Validation Accuracy: 92.12%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 87.80% | Validation Accuracy: 92.58%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 88.03% | Validation Accuracy: 92.74%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 88.13% | Validation Accuracy: 92.86%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 88.63% | Validation Accuracy: 92.73%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 88.79% | Validation Accuracy: 92.71%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 88.97% | Validation Accuracy: 93.07%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 89.22% | Validation Accuracy: 93.15%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 89.18% | Validation Accuracy: 93.32%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 89.21% | Validation Accuracy: 93.20%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 89.08% | Validation Accuracy: 92.82%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 89.31% | Validation Accuracy: 93.30%
#     Fold 2 Best Val Acc: 0.9332 (93.32)%
#     Fold 2 Total Training Time: 0.70 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 73.39% | Validation Accuracy: 88.09%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 81.53% | Validation Accuracy: 90.18%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 83.80% | Validation Accuracy: 91.23%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 85.22% | Validation Accuracy: 90.38%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 85.94% | Validation Accuracy: 92.54%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 86.19% | Validation Accuracy: 92.92%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 86.99% | Validation Accuracy: 93.32%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 87.33% | Validation Accuracy: 92.34%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 87.89% | Validation Accuracy: 93.06%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 87.88% | Validation Accuracy: 93.67%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 88.36% | Validation Accuracy: 92.81%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 88.49% | Validation Accuracy: 93.70%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 88.51% | Validation Accuracy: 93.11%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 88.38% | Validation Accuracy: 93.30%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 88.90% | Validation Accuracy: 93.61%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 88.96% | Validation Accuracy: 93.20%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 88.86% | Validation Accuracy: 93.99%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 88.99% | Validation Accuracy: 93.20%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 89.34% | Validation Accuracy: 93.91%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 89.42% | Validation Accuracy: 92.31%
#     Fold 3 Best Val Acc: 0.9399 (93.99)%
#     Fold 3 Total Training Time: 0.70 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 73.96% | Validation Accuracy: 87.49%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 81.81% | Validation Accuracy: 90.20%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 84.03% | Validation Accuracy: 90.08%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 85.34% | Validation Accuracy: 90.97%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 86.21% | Validation Accuracy: 92.24%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 86.93% | Validation Accuracy: 92.98%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 87.26% | Validation Accuracy: 92.93%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 87.74% | Validation Accuracy: 92.92%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 88.08% | Validation Accuracy: 92.33%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 88.28% | Validation Accuracy: 92.88%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 88.32% | Validation Accuracy: 93.19%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 88.28% | Validation Accuracy: 93.38%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 89.14% | Validation Accuracy: 92.98%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 88.95% | Validation Accuracy: 93.56%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 89.30% | Validation Accuracy: 93.73%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 89.58% | Validation Accuracy: 92.92%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 89.38% | Validation Accuracy: 93.40%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 89.79% | Validation Accuracy: 93.61%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 89.92% | Validation Accuracy: 93.68%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 89.89% | Validation Accuracy: 93.62%
#     Fold 4 Best Val Acc: 0.9373 (93.73)%
#     Fold 4 Total Training Time: 0.71 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 73.13% | Validation Accuracy: 86.60%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 81.73% | Validation Accuracy: 89.93%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 84.31% | Validation Accuracy: 91.11%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 85.40% | Validation Accuracy: 91.22%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 86.32% | Validation Accuracy: 91.92%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 86.95% | Validation Accuracy: 92.83%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 87.68% | Validation Accuracy: 91.27%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 87.95% | Validation Accuracy: 92.18%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 88.10% | Validation Accuracy: 92.61%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 88.48% | Validation Accuracy: 92.83%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 88.58% | Validation Accuracy: 92.89%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 89.01% | Validation Accuracy: 93.21%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 89.10% | Validation Accuracy: 93.15%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 89.36% | Validation Accuracy: 92.13%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 89.47% | Validation Accuracy: 93.37%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 89.59% | Validation Accuracy: 93.23%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 89.66% | Validation Accuracy: 91.87%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 89.45% | Validation Accuracy: 93.65%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 89.90% | Validation Accuracy: 93.25%
# Fold 5/5 Epoch 20/20 | Training Accuracy: 89.71% | Validation Accuracy: 93.34%
#     Fold 5 Best Val Acc: 0.9365 (93.65)%
#     Fold 5 Total Training Time: 0.67 mins.
# Testing config 3/9: {'lr': 0.01, 'alpha': 0.8, 'eps': 1e-08}
# Fold 1/5 Epoch 1/20 | Training Accuracy: 84.13% | Validation Accuracy: 91.09%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 89.34% | Validation Accuracy: 92.52%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 90.76% | Validation Accuracy: 93.32%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 91.89% | Validation Accuracy: 93.60%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 91.97% | Validation Accuracy: 94.05%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 92.44% | Validation Accuracy: 94.24%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 92.77% | Validation Accuracy: 94.47%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 92.98% | Validation Accuracy: 94.38%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 93.17% | Validation Accuracy: 94.73%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 93.33% | Validation Accuracy: 94.51%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 93.35% | Validation Accuracy: 94.84%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 93.65% | Validation Accuracy: 94.97%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 93.77% | Validation Accuracy: 94.73%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 93.88% | Validation Accuracy: 94.69%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 93.79% | Validation Accuracy: 94.77%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 94.00% | Validation Accuracy: 94.83%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 94.00% | Validation Accuracy: 94.97%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 94.21% | Validation Accuracy: 94.97%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 94.05% | Validation Accuracy: 95.12%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 94.26% | Validation Accuracy: 94.55%
#     Fold 1 Best Val Acc: 0.9512 (95.12)%
#     Fold 1 Total Training Time: 0.67 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 84.08% | Validation Accuracy: 91.47%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 89.42% | Validation Accuracy: 93.03%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 90.79% | Validation Accuracy: 93.97%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 91.44% | Validation Accuracy: 94.25%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 91.98% | Validation Accuracy: 94.54%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 92.50% | Validation Accuracy: 94.84%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 92.61% | Validation Accuracy: 94.50%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 92.78% | Validation Accuracy: 94.54%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 93.15% | Validation Accuracy: 94.84%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 93.26% | Validation Accuracy: 94.93%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 93.28% | Validation Accuracy: 95.01%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 93.36% | Validation Accuracy: 94.85%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 93.60% | Validation Accuracy: 95.11%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 93.73% | Validation Accuracy: 95.08%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 93.89% | Validation Accuracy: 95.00%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 93.90% | Validation Accuracy: 95.14%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 93.88% | Validation Accuracy: 95.00%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 94.02% | Validation Accuracy: 95.16%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 94.24% | Validation Accuracy: 95.02%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 94.19% | Validation Accuracy: 95.30%
#     Fold 2 Best Val Acc: 0.9530 (95.30)%
#     Fold 2 Total Training Time: 0.71 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 84.08% | Validation Accuracy: 92.23%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 89.28% | Validation Accuracy: 93.67%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 90.77% | Validation Accuracy: 94.18%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 91.58% | Validation Accuracy: 94.54%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 91.94% | Validation Accuracy: 94.78%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 92.19% | Validation Accuracy: 94.81%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 92.60% | Validation Accuracy: 95.25%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 92.96% | Validation Accuracy: 94.52%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 92.94% | Validation Accuracy: 95.01%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 93.02% | Validation Accuracy: 95.19%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 93.34% | Validation Accuracy: 95.17%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 93.43% | Validation Accuracy: 95.15%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 93.56% | Validation Accuracy: 95.23%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 93.71% | Validation Accuracy: 95.02%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 93.73% | Validation Accuracy: 95.21%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 93.92% | Validation Accuracy: 95.30%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 93.94% | Validation Accuracy: 95.47%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 94.01% | Validation Accuracy: 95.11%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 93.99% | Validation Accuracy: 95.49%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 94.17% | Validation Accuracy: 94.99%
#     Fold 3 Best Val Acc: 0.9549 (95.49)%
#     Fold 3 Total Training Time: 0.72 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 83.82% | Validation Accuracy: 92.11%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 89.23% | Validation Accuracy: 93.81%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 90.63% | Validation Accuracy: 93.92%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 91.32% | Validation Accuracy: 94.26%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 92.04% | Validation Accuracy: 94.74%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 92.26% | Validation Accuracy: 94.84%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 92.59% | Validation Accuracy: 94.92%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 93.03% | Validation Accuracy: 94.87%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 93.18% | Validation Accuracy: 95.06%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 93.24% | Validation Accuracy: 95.21%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 93.34% | Validation Accuracy: 95.23%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 93.40% | Validation Accuracy: 95.16%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 93.77% | Validation Accuracy: 95.13%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 93.95% | Validation Accuracy: 94.98%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 93.88% | Validation Accuracy: 95.34%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 93.88% | Validation Accuracy: 95.09%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 94.11% | Validation Accuracy: 95.10%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 94.12% | Validation Accuracy: 95.08%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 93.88% | Validation Accuracy: 95.36%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 94.20% | Validation Accuracy: 95.58%
#     Fold 4 Best Val Acc: 0.9558 (95.58)%
#     Fold 4 Total Training Time: 0.71 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 84.09% | Validation Accuracy: 91.82%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 89.39% | Validation Accuracy: 93.23%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 90.79% | Validation Accuracy: 93.82%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 91.54% | Validation Accuracy: 94.20%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 91.99% | Validation Accuracy: 94.27%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 92.42% | Validation Accuracy: 94.54%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 92.56% | Validation Accuracy: 94.64%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 92.92% | Validation Accuracy: 94.62%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 92.86% | Validation Accuracy: 94.77%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 93.27% | Validation Accuracy: 95.03%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 93.46% | Validation Accuracy: 94.77%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 93.41% | Validation Accuracy: 94.79%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 93.70% | Validation Accuracy: 94.76%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 93.77% | Validation Accuracy: 95.05%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 93.81% | Validation Accuracy: 94.67%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 93.88% | Validation Accuracy: 94.77%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 93.92% | Validation Accuracy: 94.89%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 94.00% | Validation Accuracy: 94.81%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 94.02% | Validation Accuracy: 94.92%
# Fold 5/5 Epoch 20/20 | Training Accuracy: 94.19% | Validation Accuracy: 94.88%
#     Fold 5 Best Val Acc: 0.9505 (95.05)%
#     Fold 5 Total Training Time: 0.72 mins.
# Testing config 4/9: {'lr': 0.001, 'alpha': 0.99, 'eps': 1e-08}
# Fold 1/5 Epoch 1/20 | Training Accuracy: 82.98% | Validation Accuracy: 90.57%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 88.89% | Validation Accuracy: 92.38%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 90.67% | Validation Accuracy: 93.20%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 91.62% | Validation Accuracy: 93.80%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 92.42% | Validation Accuracy: 94.10%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 92.99% | Validation Accuracy: 94.55%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 93.53% | Validation Accuracy: 94.50%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 93.76% | Validation Accuracy: 94.74%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 94.11% | Validation Accuracy: 94.58%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 94.37% | Validation Accuracy: 94.70%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 94.62% | Validation Accuracy: 94.86%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 94.71% | Validation Accuracy: 95.02%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 94.91% | Validation Accuracy: 94.92%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 95.01% | Validation Accuracy: 94.98%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 95.20% | Validation Accuracy: 94.89%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 95.47% | Validation Accuracy: 94.95%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 95.60% | Validation Accuracy: 95.08%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 95.71% | Validation Accuracy: 95.28%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 95.62% | Validation Accuracy: 95.25%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 95.78% | Validation Accuracy: 95.13%
#     Fold 1 Best Val Acc: 0.9528 (95.28)%
#     Fold 1 Total Training Time: 0.72 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 82.97% | Validation Accuracy: 91.17%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 88.76% | Validation Accuracy: 92.98%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 90.51% | Validation Accuracy: 93.75%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 91.75% | Validation Accuracy: 94.36%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 92.38% | Validation Accuracy: 94.83%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 93.09% | Validation Accuracy: 94.96%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 93.49% | Validation Accuracy: 95.18%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 93.91% | Validation Accuracy: 95.18%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 94.25% | Validation Accuracy: 95.47%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 94.55% | Validation Accuracy: 95.50%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 94.57% | Validation Accuracy: 95.47%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 94.91% | Validation Accuracy: 95.41%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 95.07% | Validation Accuracy: 95.61%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 95.12% | Validation Accuracy: 95.46%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 95.25% | Validation Accuracy: 95.63%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 95.53% | Validation Accuracy: 95.58%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 95.61% | Validation Accuracy: 95.47%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 95.76% | Validation Accuracy: 95.57%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 95.66% | Validation Accuracy: 95.56%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 95.91% | Validation Accuracy: 95.53%
#     Fold 2 Best Val Acc: 0.9563 (95.63)%
#     Fold 2 Total Training Time: 0.76 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 82.84% | Validation Accuracy: 91.90%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 88.74% | Validation Accuracy: 93.23%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 90.53% | Validation Accuracy: 94.11%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 91.77% | Validation Accuracy: 94.51%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 92.41% | Validation Accuracy: 94.79%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 92.89% | Validation Accuracy: 95.28%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 93.41% | Validation Accuracy: 95.35%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 93.81% | Validation Accuracy: 95.36%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 94.12% | Validation Accuracy: 95.49%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 94.56% | Validation Accuracy: 95.47%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 94.71% | Validation Accuracy: 95.59%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 94.71% | Validation Accuracy: 95.79%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 95.16% | Validation Accuracy: 95.64%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 95.11% | Validation Accuracy: 95.82%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 95.33% | Validation Accuracy: 95.87%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 95.56% | Validation Accuracy: 95.78%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 95.55% | Validation Accuracy: 95.89%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 95.64% | Validation Accuracy: 96.00%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 95.66% | Validation Accuracy: 95.97%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 95.76% | Validation Accuracy: 95.78%
#     Fold 3 Best Val Acc: 0.9600 (96.00)%
#     Fold 3 Total Training Time: 0.71 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 82.79% | Validation Accuracy: 91.36%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 88.43% | Validation Accuracy: 93.27%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 90.50% | Validation Accuracy: 94.22%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 91.60% | Validation Accuracy: 94.58%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 92.37% | Validation Accuracy: 94.99%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 92.92% | Validation Accuracy: 95.14%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 93.43% | Validation Accuracy: 95.08%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 93.87% | Validation Accuracy: 95.23%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 94.20% | Validation Accuracy: 95.12%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 94.42% | Validation Accuracy: 95.41%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 94.72% | Validation Accuracy: 95.39%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 94.71% | Validation Accuracy: 95.43%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 94.85% | Validation Accuracy: 95.49%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 95.18% | Validation Accuracy: 95.73%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 95.17% | Validation Accuracy: 95.76%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 95.46% | Validation Accuracy: 95.74%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 95.61% | Validation Accuracy: 95.80%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 95.70% | Validation Accuracy: 95.70%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 95.76% | Validation Accuracy: 95.68%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 95.90% | Validation Accuracy: 95.85%
#     Fold 4 Best Val Acc: 0.9585 (95.85)%
#     Fold 4 Total Training Time: 0.77 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 82.76% | Validation Accuracy: 91.42%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 88.95% | Validation Accuracy: 92.93%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 90.74% | Validation Accuracy: 93.61%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 91.67% | Validation Accuracy: 94.16%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 92.56% | Validation Accuracy: 94.29%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 93.19% | Validation Accuracy: 94.58%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 93.42% | Validation Accuracy: 94.76%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 94.03% | Validation Accuracy: 95.07%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 94.12% | Validation Accuracy: 95.24%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 94.33% | Validation Accuracy: 94.96%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 94.69% | Validation Accuracy: 95.15%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 94.75% | Validation Accuracy: 95.09%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 95.05% | Validation Accuracy: 95.41%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 95.17% | Validation Accuracy: 95.19%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 95.30% | Validation Accuracy: 95.16%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 95.54% | Validation Accuracy: 95.18%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 95.42% | Validation Accuracy: 95.16%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 95.82% | Validation Accuracy: 95.51%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 95.79% | Validation Accuracy: 95.43%
# Fold 5/5 Epoch 20/20 | Training Accuracy: 95.83% | Validation Accuracy: 95.36%
#     Fold 5 Best Val Acc: 0.9551 (95.51)%
#     Fold 5 Total Training Time: 0.75 mins.
# Testing config 5/9: {'lr': 0.0001, 'alpha': 0.99, 'eps': 1e-08}
# Fold 1/5 Epoch 1/20 | Training Accuracy: 65.89% | Validation Accuracy: 81.79%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 79.54% | Validation Accuracy: 85.50%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 82.84% | Validation Accuracy: 87.34%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 84.76% | Validation Accuracy: 88.65%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 86.16% | Validation Accuracy: 89.46%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 86.98% | Validation Accuracy: 90.25%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 87.89% | Validation Accuracy: 90.89%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 88.50% | Validation Accuracy: 91.20%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 89.15% | Validation Accuracy: 91.57%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 89.61% | Validation Accuracy: 91.96%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 89.84% | Validation Accuracy: 92.17%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 90.17% | Validation Accuracy: 92.56%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 90.52% | Validation Accuracy: 92.92%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 90.78% | Validation Accuracy: 93.02%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 91.02% | Validation Accuracy: 93.19%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 91.50% | Validation Accuracy: 93.40%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 91.74% | Validation Accuracy: 93.42%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 92.01% | Validation Accuracy: 93.53%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 91.88% | Validation Accuracy: 93.67%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 92.29% | Validation Accuracy: 93.78%
#     Fold 1 Best Val Acc: 0.9378 (93.78)%
#     Fold 1 Total Training Time: 0.80 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 66.01% | Validation Accuracy: 81.73%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 79.37% | Validation Accuracy: 85.76%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 82.61% | Validation Accuracy: 87.62%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 84.78% | Validation Accuracy: 89.12%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 86.08% | Validation Accuracy: 89.98%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 87.02% | Validation Accuracy: 90.70%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 87.54% | Validation Accuracy: 91.23%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 88.37% | Validation Accuracy: 91.71%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 88.80% | Validation Accuracy: 91.98%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 89.39% | Validation Accuracy: 92.27%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 89.78% | Validation Accuracy: 92.71%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 90.07% | Validation Accuracy: 92.88%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 90.39% | Validation Accuracy: 93.31%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 90.73% | Validation Accuracy: 93.45%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 91.00% | Validation Accuracy: 93.47%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 91.37% | Validation Accuracy: 93.73%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 91.50% | Validation Accuracy: 93.85%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 91.76% | Validation Accuracy: 93.92%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 91.97% | Validation Accuracy: 94.22%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 92.13% | Validation Accuracy: 94.38%
#     Fold 2 Best Val Acc: 0.9438 (94.38)%
#     Fold 2 Total Training Time: 0.84 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 65.89% | Validation Accuracy: 82.16%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 79.11% | Validation Accuracy: 86.36%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 82.59% | Validation Accuracy: 88.28%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 84.82% | Validation Accuracy: 89.23%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 85.81% | Validation Accuracy: 90.43%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 86.94% | Validation Accuracy: 91.15%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 87.60% | Validation Accuracy: 91.78%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 88.25% | Validation Accuracy: 92.23%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 88.86% | Validation Accuracy: 92.50%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 89.32% | Validation Accuracy: 92.63%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 89.73% | Validation Accuracy: 92.97%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 90.06% | Validation Accuracy: 93.12%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 90.61% | Validation Accuracy: 93.34%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 90.76% | Validation Accuracy: 93.69%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 91.14% | Validation Accuracy: 93.83%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 91.35% | Validation Accuracy: 93.88%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 91.56% | Validation Accuracy: 94.04%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 91.73% | Validation Accuracy: 94.09%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 92.00% | Validation Accuracy: 94.28%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 92.20% | Validation Accuracy: 94.45%
#     Fold 3 Best Val Acc: 0.9445 (94.45)%
#     Fold 3 Total Training Time: 0.77 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 66.04% | Validation Accuracy: 81.98%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 79.21% | Validation Accuracy: 86.23%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 82.78% | Validation Accuracy: 88.43%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 84.52% | Validation Accuracy: 89.62%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 85.73% | Validation Accuracy: 90.33%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 86.92% | Validation Accuracy: 90.98%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 87.63% | Validation Accuracy: 91.68%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 88.36% | Validation Accuracy: 92.07%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 88.97% | Validation Accuracy: 92.46%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 89.41% | Validation Accuracy: 92.83%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 89.71% | Validation Accuracy: 93.06%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 90.25% | Validation Accuracy: 93.13%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 90.37% | Validation Accuracy: 93.23%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 90.83% | Validation Accuracy: 93.47%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 90.91% | Validation Accuracy: 93.83%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 91.26% | Validation Accuracy: 93.88%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 91.58% | Validation Accuracy: 93.97%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 91.74% | Validation Accuracy: 94.08%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 91.81% | Validation Accuracy: 94.38%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 92.33% | Validation Accuracy: 94.40%
#     Fold 4 Best Val Acc: 0.9440 (94.40)%
#     Fold 4 Total Training Time: 0.77 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 66.11% | Validation Accuracy: 81.51%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 79.30% | Validation Accuracy: 85.88%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 82.84% | Validation Accuracy: 87.75%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 84.49% | Validation Accuracy: 89.10%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 86.04% | Validation Accuracy: 90.03%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 86.94% | Validation Accuracy: 90.82%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 87.72% | Validation Accuracy: 91.17%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 88.60% | Validation Accuracy: 91.68%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 88.80% | Validation Accuracy: 92.07%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 89.40% | Validation Accuracy: 92.26%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 89.73% | Validation Accuracy: 92.56%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 90.14% | Validation Accuracy: 92.70%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 90.58% | Validation Accuracy: 92.92%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 90.63% | Validation Accuracy: 93.04%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 91.09% | Validation Accuracy: 93.23%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 91.52% | Validation Accuracy: 93.45%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 91.68% | Validation Accuracy: 93.42%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 91.93% | Validation Accuracy: 93.51%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 92.15% | Validation Accuracy: 93.72%
# Fold 5/5 Epoch 20/20 | Training Accuracy: 92.17% | Validation Accuracy: 93.74%
#     Fold 5 Best Val Acc: 0.9374 (93.74)%
#     Fold 5 Total Training Time: 0.76 mins.
# Testing config 6/9: {'lr': 0.01, 'alpha': 0.99, 'eps': 1e-08, 'weight_decay': 0.0001}
# Fold 1/5 Epoch 1/20 | Training Accuracy: 83.75% | Validation Accuracy: 91.13%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 87.95% | Validation Accuracy: 92.42%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 88.63% | Validation Accuracy: 91.22%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 89.29% | Validation Accuracy: 92.12%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 89.30% | Validation Accuracy: 92.18%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 89.38% | Validation Accuracy: 92.53%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 89.46% | Validation Accuracy: 92.80%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 89.58% | Validation Accuracy: 92.73%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 89.74% | Validation Accuracy: 92.64%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 89.56% | Validation Accuracy: 92.92%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 89.60% | Validation Accuracy: 92.99%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 89.65% | Validation Accuracy: 92.82%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 89.77% | Validation Accuracy: 92.64%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 89.64% | Validation Accuracy: 92.72%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 89.85% | Validation Accuracy: 93.17%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 89.91% | Validation Accuracy: 92.42%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 89.95% | Validation Accuracy: 93.02%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 89.94% | Validation Accuracy: 92.80%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 89.94% | Validation Accuracy: 92.97%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 89.88% | Validation Accuracy: 92.84%
#     Fold 1 Best Val Acc: 0.9317 (93.17)%
#     Fold 1 Total Training Time: 0.84 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 83.53% | Validation Accuracy: 91.17%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 88.21% | Validation Accuracy: 91.92%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 88.73% | Validation Accuracy: 92.86%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 89.03% | Validation Accuracy: 92.55%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 89.21% | Validation Accuracy: 92.12%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 89.45% | Validation Accuracy: 93.10%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 89.58% | Validation Accuracy: 92.82%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 89.55% | Validation Accuracy: 92.97%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 89.57% | Validation Accuracy: 93.03%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 89.74% | Validation Accuracy: 93.03%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 89.72% | Validation Accuracy: 92.93%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 89.78% | Validation Accuracy: 92.73%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 89.73% | Validation Accuracy: 93.42%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 89.61% | Validation Accuracy: 93.73%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 89.78% | Validation Accuracy: 93.77%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 89.85% | Validation Accuracy: 93.69%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 89.88% | Validation Accuracy: 92.80%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 89.78% | Validation Accuracy: 93.27%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 89.75% | Validation Accuracy: 93.29%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 89.75% | Validation Accuracy: 92.87%
#     Fold 2 Best Val Acc: 0.9377 (93.77)%
#     Fold 2 Total Training Time: 0.84 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 83.68% | Validation Accuracy: 91.96%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 88.07% | Validation Accuracy: 92.88%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 88.80% | Validation Accuracy: 93.57%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 89.11% | Validation Accuracy: 93.03%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 89.28% | Validation Accuracy: 93.29%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 89.32% | Validation Accuracy: 93.18%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 89.34% | Validation Accuracy: 93.55%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 89.43% | Validation Accuracy: 92.47%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 89.65% | Validation Accuracy: 93.55%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 89.69% | Validation Accuracy: 93.57%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 89.68% | Validation Accuracy: 93.92%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 89.58% | Validation Accuracy: 93.41%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 89.78% | Validation Accuracy: 93.81%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 89.67% | Validation Accuracy: 93.26%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 89.69% | Validation Accuracy: 93.45%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 89.54% | Validation Accuracy: 93.39%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 89.70% | Validation Accuracy: 93.88%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 89.62% | Validation Accuracy: 93.24%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 89.71% | Validation Accuracy: 94.21%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 89.75% | Validation Accuracy: 93.33%
#     Fold 3 Best Val Acc: 0.9421 (94.21)%
#     Fold 3 Total Training Time: 0.81 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 83.47% | Validation Accuracy: 90.72%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 87.82% | Validation Accuracy: 92.15%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 88.59% | Validation Accuracy: 92.27%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 88.96% | Validation Accuracy: 93.01%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 89.06% | Validation Accuracy: 92.66%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 89.23% | Validation Accuracy: 93.26%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 89.52% | Validation Accuracy: 93.65%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 89.50% | Validation Accuracy: 92.93%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 89.56% | Validation Accuracy: 92.98%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 89.59% | Validation Accuracy: 92.83%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 89.60% | Validation Accuracy: 93.51%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 89.80% | Validation Accuracy: 93.33%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 89.68% | Validation Accuracy: 93.57%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 89.72% | Validation Accuracy: 93.29%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 89.81% | Validation Accuracy: 92.79%
# ...
# Fold 1/5 Epoch 11/20 | Training Accuracy: 73.22% | Validation Accuracy: 75.58%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 73.01% | Validation Accuracy: 80.40%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 73.15% | Validation Accuracy: 72.89%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 73.17% | Validation Accuracy: 74.50%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 73.16% | Validation Accuracy: 74.54%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 73.33% | Validation Accuracy: 73.00%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 73.04% | Validation Accuracy: 77.45%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 73.11% | Validation Accuracy: 80.54%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 72.83% | Validation Accuracy: 77.44%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 72.99% | Validation Accuracy: 77.16%
#     Fold 1 Best Val Acc: 0.8054 (80.54)%
#     Fold 1 Total Training Time: 0.85 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 71.04% | Validation Accuracy: 77.75%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 73.40% | Validation Accuracy: 78.61%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 73.15% | Validation Accuracy: 79.88%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 73.20% | Validation Accuracy: 77.11%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 73.37% | Validation Accuracy: 79.02%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 72.97% | Validation Accuracy: 79.51%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 73.21% | Validation Accuracy: 77.37%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 73.08% | Validation Accuracy: 76.28%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 73.30% | Validation Accuracy: 60.96%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 73.27% | Validation Accuracy: 77.24%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 73.22% | Validation Accuracy: 79.09%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 73.14% | Validation Accuracy: 80.17%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 73.31% | Validation Accuracy: 76.33%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 73.49% | Validation Accuracy: 76.85%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 73.21% | Validation Accuracy: 78.06%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 73.36% | Validation Accuracy: 79.89%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 73.18% | Validation Accuracy: 76.33%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 73.38% | Validation Accuracy: 79.12%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 73.27% | Validation Accuracy: 76.15%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 73.16% | Validation Accuracy: 75.62%
#     Fold 2 Best Val Acc: 0.8017 (80.17)%
#     Fold 2 Total Training Time: 0.92 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 70.41% | Validation Accuracy: 77.42%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 73.22% | Validation Accuracy: 80.05%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 73.17% | Validation Accuracy: 41.08%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 73.25% | Validation Accuracy: 77.16%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 73.15% | Validation Accuracy: 80.18%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 72.97% | Validation Accuracy: 81.39%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 73.22% | Validation Accuracy: 76.97%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 73.19% | Validation Accuracy: 77.61%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 73.38% | Validation Accuracy: 72.59%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 72.84% | Validation Accuracy: 79.22%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 72.87% | Validation Accuracy: 81.91%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 73.08% | Validation Accuracy: 79.83%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 73.22% | Validation Accuracy: 79.09%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 73.37% | Validation Accuracy: 80.40%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 73.09% | Validation Accuracy: 76.48%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 72.96% | Validation Accuracy: 78.52%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 73.18% | Validation Accuracy: 77.50%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 73.02% | Validation Accuracy: 77.66%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 73.16% | Validation Accuracy: 78.49%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 73.11% | Validation Accuracy: 81.09%
#     Fold 3 Best Val Acc: 0.8191 (81.91)%
#     Fold 3 Total Training Time: 0.93 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 70.80% | Validation Accuracy: 76.52%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 72.85% | Validation Accuracy: 80.77%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 73.42% | Validation Accuracy: 77.26%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 73.18% | Validation Accuracy: 80.94%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 73.31% | Validation Accuracy: 79.57%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 72.84% | Validation Accuracy: 77.88%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 72.89% | Validation Accuracy: 80.54%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 72.98% | Validation Accuracy: 74.62%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 73.08% | Validation Accuracy: 78.20%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 73.37% | Validation Accuracy: 79.53%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 72.60% | Validation Accuracy: 78.03%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 72.95% | Validation Accuracy: 79.40%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 73.24% | Validation Accuracy: 77.68%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 72.89% | Validation Accuracy: 80.75%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 72.91% | Validation Accuracy: 79.92%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 73.00% | Validation Accuracy: 79.76%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 73.14% | Validation Accuracy: 81.34%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 72.88% | Validation Accuracy: 73.88%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 73.03% | Validation Accuracy: 77.92%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 73.02% | Validation Accuracy: 79.09%
#     Fold 4 Best Val Acc: 0.8134 (81.34)%
#     Fold 4 Total Training Time: 0.81 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 71.08% | Validation Accuracy: 74.03%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 73.25% | Validation Accuracy: 69.89%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 73.03% | Validation Accuracy: 78.05%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 73.26% | Validation Accuracy: 81.49%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 72.83% | Validation Accuracy: 79.88%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 73.29% | Validation Accuracy: 78.78%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 73.10% | Validation Accuracy: 79.39%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 73.00% | Validation Accuracy: 76.20%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 72.99% | Validation Accuracy: 79.89%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 73.10% | Validation Accuracy: 79.67%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 72.93% | Validation Accuracy: 79.67%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 72.65% | Validation Accuracy: 79.66%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 72.88% | Validation Accuracy: 79.70%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 72.89% | Validation Accuracy: 74.86%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 73.25% | Validation Accuracy: 81.38%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 73.06% | Validation Accuracy: 74.50%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 73.29% | Validation Accuracy: 79.03%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 73.08% | Validation Accuracy: 79.12%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 73.02% | Validation Accuracy: 74.48%
# Fold 5/5 Epoch 20/20 | Training Accuracy: 73.13% | Validation Accuracy: 71.54%
#     Fold 5 Best Val Acc: 0.8149 (81.49)%
#     Fold 5 Total Training Time: 0.84 mins.
# Testing config 9/9: {'lr': 0.01, 'alpha': 0.99, 'eps': 1e-07, 'momentum': 0.003}
# Fold 1/5 Epoch 1/20 | Training Accuracy: 84.52% | Validation Accuracy: 91.93%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 89.93% | Validation Accuracy: 93.14%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 91.46% | Validation Accuracy: 93.53%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 92.20% | Validation Accuracy: 94.15%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 92.75% | Validation Accuracy: 94.55%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 93.08% | Validation Accuracy: 94.99%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 93.57% | Validation Accuracy: 95.08%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 93.63% | Validation Accuracy: 95.16%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 94.19% | Validation Accuracy: 95.03%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 94.31% | Validation Accuracy: 95.11%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 94.39% | Validation Accuracy: 94.92%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 94.68% | Validation Accuracy: 95.06%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 94.88% | Validation Accuracy: 95.28%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 94.80% | Validation Accuracy: 95.14%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 94.88% | Validation Accuracy: 95.25%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 95.24% | Validation Accuracy: 95.28%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 95.06% | Validation Accuracy: 95.32%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 95.36% | Validation Accuracy: 95.35%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 95.40% | Validation Accuracy: 95.43%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 95.45% | Validation Accuracy: 95.43%
#     Fold 1 Best Val Acc: 0.9543 (95.43)%
#     Fold 1 Total Training Time: 0.83 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 84.23% | Validation Accuracy: 91.88%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 89.66% | Validation Accuracy: 93.71%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 91.19% | Validation Accuracy: 94.35%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 92.05% | Validation Accuracy: 94.48%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 92.52% | Validation Accuracy: 94.79%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 93.06% | Validation Accuracy: 95.00%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 93.44% | Validation Accuracy: 95.28%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 93.63% | Validation Accuracy: 95.14%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 93.83% | Validation Accuracy: 95.12%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 94.29% | Validation Accuracy: 95.53%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 94.47% | Validation Accuracy: 95.39%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 94.54% | Validation Accuracy: 95.58%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 94.73% | Validation Accuracy: 95.48%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 94.71% | Validation Accuracy: 95.68%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 94.94% | Validation Accuracy: 95.75%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 95.10% | Validation Accuracy: 95.67%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 95.16% | Validation Accuracy: 95.67%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 95.32% | Validation Accuracy: 95.68%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 95.38% | Validation Accuracy: 95.75%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 95.42% | Validation Accuracy: 95.69%
#     Fold 2 Best Val Acc: 0.9575 (95.75)%
#     Fold 2 Total Training Time: 1.01 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 84.30% | Validation Accuracy: 93.10%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 89.66% | Validation Accuracy: 93.97%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 91.35% | Validation Accuracy: 94.53%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 92.10% | Validation Accuracy: 94.59%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 92.72% | Validation Accuracy: 94.86%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 93.16% | Validation Accuracy: 95.09%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 93.42% | Validation Accuracy: 95.22%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 93.81% | Validation Accuracy: 94.88%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 93.97% | Validation Accuracy: 95.56%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 94.24% | Validation Accuracy: 95.52%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 94.41% | Validation Accuracy: 95.47%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 94.47% | Validation Accuracy: 95.83%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 94.65% | Validation Accuracy: 95.62%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 94.71% | Validation Accuracy: 95.58%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 94.96% | Validation Accuracy: 95.68%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 95.00% | Validation Accuracy: 95.67%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 95.04% | Validation Accuracy: 95.76%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 95.23% | Validation Accuracy: 95.83%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 95.37% | Validation Accuracy: 95.87%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 95.53% | Validation Accuracy: 95.66%
#     Fold 3 Best Val Acc: 0.9587 (95.87)%
#     Fold 3 Total Training Time: 1.00 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 84.17% | Validation Accuracy: 92.07%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 89.55% | Validation Accuracy: 93.82%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 91.12% | Validation Accuracy: 94.21%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 91.89% | Validation Accuracy: 94.71%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 92.54% | Validation Accuracy: 94.88%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 92.88% | Validation Accuracy: 95.24%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 93.45% | Validation Accuracy: 95.34%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 93.65% | Validation Accuracy: 94.87%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 93.89% | Validation Accuracy: 95.23%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 94.19% | Validation Accuracy: 95.23%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 94.19% | Validation Accuracy: 95.36%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 94.35% | Validation Accuracy: 95.57%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 94.67% | Validation Accuracy: 95.58%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 94.83% | Validation Accuracy: 95.53%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 94.84% | Validation Accuracy: 95.52%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 94.82% | Validation Accuracy: 95.55%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 95.10% | Validation Accuracy: 95.76%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 95.25% | Validation Accuracy: 95.63%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 95.27% | Validation Accuracy: 95.61%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 95.35% | Validation Accuracy: 95.71%
#     Fold 4 Best Val Acc: 0.9576 (95.76)%
#     Fold 4 Total Training Time: 1.04 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 84.39% | Validation Accuracy: 92.44%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 89.83% | Validation Accuracy: 93.25%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 91.22% | Validation Accuracy: 94.00%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 91.95% | Validation Accuracy: 94.62%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 92.68% | Validation Accuracy: 94.75%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 93.37% | Validation Accuracy: 94.76%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 93.73% | Validation Accuracy: 94.97%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 93.82% | Validation Accuracy: 95.26%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 94.13% | Validation Accuracy: 94.90%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 94.36% | Validation Accuracy: 95.16%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 94.58% | Validation Accuracy: 95.30%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 94.60% | Validation Accuracy: 95.47%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 94.83% | Validation Accuracy: 95.23%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 94.73% | Validation Accuracy: 95.28%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 94.95% | Validation Accuracy: 95.23%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 95.08% | Validation Accuracy: 95.42%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 95.30% | Validation Accuracy: 95.39%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 95.33% | Validation Accuracy: 95.45%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 95.49% | Validation Accuracy: 95.63%
# Fold 5/5 Epoch 20/20 | Training Accuracy: 95.35% | Validation Accuracy: 95.37%
#     Fold 5 Best Val Acc: 0.9563 (95.63)%
#     Fold 5 Total Training Time: 0.98 mins.
# Best configuration: {'lr': 0.01, 'alpha': 0.99, 'eps': 1e-08}
# Mean Validation Accuracy: 0.9579

# %% [markdown]
# ### Optuna Installation

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import sys
# !{sys.executable} -m pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.9.0-py3-none-any.whl.metadata (15 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.18.4-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in C:\Users\KJ\.conda\envs\py-tf-torch-env\Lib\site-packages (from optuna) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\KJ\.conda\envs\py-tf-torch-env\Lib\site-packages (from optuna) (26.0)
# Collecting sqlalchemy>=1.4.2 (from optuna)
#   Downloading sqlalchemy-2.0.51-cp312-cp312-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: tqdm in C:\Users\KJ\.conda\envs\py-tf-torch-env\Lib\site-packages (from optuna) (4.68.2)
# Requirement already satisfied: PyYAML in C:\Users\KJ\.conda\envs\py-tf-torch-env\Lib\site-packages (from optuna) (6.0.3)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading mako-1.3.12-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.12 in C:\Users\KJ\.conda\envs\py-tf-torch-env\Lib\site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Collecting greenlet>=1 (from sqlalchemy>=1.4.2->optuna)
#   Downloading greenlet-3.5.2-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: colorama in C:\Users\KJ\.conda\envs\py-tf-torch-env\Lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in C:\Users\KJ\.conda\envs\py-tf-torch-env\Lib\site-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.9.0-py3-none-any.whl (425 kB)
# Downloading alembic-1.18.4-py3-none-any.whl (263 kB)
# Downloading sqlalchemy-2.0.51-cp312-cp312-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.1 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 15.1 MB/s  0:00:00
# Downloading greenlet-3.5.2-cp312-cp312-win_amd64.whl (239 kB)
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading mako-1.3.12-py3-none-any.whl (78 kB)
# Installing collected packages: Mako, greenlet, colorlog, sqlalchemy, alembic, optuna
#
#    ------ --------------------------------- 1/6 [greenlet]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------- ------------------- 3/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [alembic]
#    -------------------------- ------------- 4/6 [alembic]
#    -------------------------- ------------- 4/6 [alembic]
#    --------------------------------- ------ 5/6 [optuna]
#    --------------------------------- ------ 5/6 [optuna]
#    --------------------------------- ------ 5/6 [optuna]
#    --------------------------------- ------ 5/6 [optuna]
#    --------------------------------- ------ 5/6 [optuna]
#    ---------------------------------------- 6/6 [optuna]
#
# Successfully installed Mako-1.3.12 alembic-1.18.4 colorlog-6.10.1 greenlet-3.5.2 optuna-4.9.0 sqlalchemy-2.0.51

# %%
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)  # cleaner output

optimizer_name = "RMSprop"
optimizer_class = torch.optim.RMSprop

loss_histories = {}
best_configuration_results = {}

def objective(trial):
    # Optuna suggests hyperparameters instead of your manual list
    config_kwargs = {
        "lr":           trial.suggest_float("lr",           1e-5, 1e-1, log=True),
        "alpha":        trial.suggest_float("alpha",        0.8,  0.99),
        "eps":          trial.suggest_float("eps",          1e-9, 1e-6, log=True),
        "momentum":     trial.suggest_float("momentum",     0.0,  0.9),
        "weight_decay": trial.suggest_float("weight_decay", 1e-5, 1e-2, log=True),
    }

    result = cross_validate_config(
        model_class=FeedForwardNet,
        train_dataset=trainset,
        optimizer_class=optimizer_class,
        optimizer_kwargs=config_kwargs,
        criterion=nn.CrossEntropyLoss(),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        device=device
    )

    loss_histories[str(config_kwargs)] = {
        "train": result[2],
        "val":   result[3],
    }

    return result[0]  # validation accuracy — Optuna maximizes this


# Run the study 
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=20, show_progress_bar=True)

# Pull out best results 
best_config_params = study.best_params
best_config_score  = study.best_value

print(f"Best configuration: {best_config_params}")
print(f"Mean Validation Accuracy: {best_config_score:.4f}")

best_configuration_results[optimizer_name] = {
    "params":  best_config_params,
    "metrics": None,  # re-run with best_config_params if you need this
}

val_loss_configs_map = {}
plt.figure(figsize=(12, 8))
config_id = 0
for label, losses in loss_histories.items():
    config_id += 1
    cid = f"config_{config_id}"
    val_loss_configs_map[cid] = label 
    plt.plot(range(1, len(losses["val"]) + 1), losses["val"], marker='o', label=cid)
plt.xlabel('Epoch')
plt.ylabel('Validation Loss')
plt.title('RMSprop: Validation Loss by Hyperparameter Configuration')
plt.legend()
plt.show()

train_loss_config_map = {}
plt.figure(figsize=(12, 8))
config_id = 0
for label, losses in loss_histories.items():
    config_id += 1
    cid = f"config_{config_id}"
    train_loss_config_map[cid] = label
    plt.plot(range(1, len(losses["train"]) + 1), losses["train"], marker='o', label=cid)
plt.xlabel('Epoch')
plt.ylabel('Training Loss')
plt.title('RMSprop: Training Loss by Hyperparameter Configuration')
plt.legend()
plt.show()
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Fold 1/5 Epoch 1/20 | Training Accuracy: 81.52% | Validation Accuracy: 87.33%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 84.29% | Validation Accuracy: 87.73%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 84.52% | Validation Accuracy: 88.73%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 84.59% | Validation Accuracy: 88.08%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 84.54% | Validation Accuracy: 87.88%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 84.58% | Validation Accuracy: 88.50%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 84.15% | Validation Accuracy: 88.67%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 84.42% | Validation Accuracy: 88.81%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 84.17% | Validation Accuracy: 87.81%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 84.32% | Validation Accuracy: 88.57%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 84.13% | Validation Accuracy: 88.33%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 84.32% | Validation Accuracy: 88.76%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 84.34% | Validation Accuracy: 88.78%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 84.28% | Validation Accuracy: 88.18%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 84.12% | Validation Accuracy: 88.39%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 84.23% | Validation Accuracy: 88.43%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 83.93% | Validation Accuracy: 87.89%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 84.22% | Validation Accuracy: 88.17%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 84.13% | Validation Accuracy: 87.24%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 84.28% | Validation Accuracy: 87.48%
#     Fold 1 Best Val Acc: 0.8881 (88.81)%
#     Fold 1 Total Training Time: 4.24 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 81.44% | Validation Accuracy: 86.85%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 84.12% | Validation Accuracy: 88.03%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 84.49% | Validation Accuracy: 88.48%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 84.39% | Validation Accuracy: 87.75%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 84.41% | Validation Accuracy: 87.96%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 84.23% | Validation Accuracy: 88.74%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 84.38% | Validation Accuracy: 88.30%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 84.35% | Validation Accuracy: 88.50%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 84.30% | Validation Accuracy: 88.03%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 84.03% | Validation Accuracy: 89.02%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 84.19% | Validation Accuracy: 88.07%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 84.28% | Validation Accuracy: 88.78%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 84.11% | Validation Accuracy: 88.83%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 84.14% | Validation Accuracy: 88.45%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 84.15% | Validation Accuracy: 88.86%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 84.24% | Validation Accuracy: 88.28%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 84.12% | Validation Accuracy: 87.80%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 84.21% | Validation Accuracy: 87.84%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 84.21% | Validation Accuracy: 88.62%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 84.22% | Validation Accuracy: 89.09%
#     Fold 2 Best Val Acc: 0.8909 (89.09)%
#     Fold 2 Total Training Time: 4.29 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 81.19% | Validation Accuracy: 87.57%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 84.42% | Validation Accuracy: 88.83%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 84.45% | Validation Accuracy: 88.15%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 84.30% | Validation Accuracy: 88.44%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 84.11% | Validation Accuracy: 89.05%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 84.27% | Validation Accuracy: 88.93%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 84.10% | Validation Accuracy: 89.17%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 84.14% | Validation Accuracy: 88.69%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 83.89% | Validation Accuracy: 89.42%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 84.23% | Validation Accuracy: 88.58%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 83.84% | Validation Accuracy: 88.18%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 84.11% | Validation Accuracy: 89.76%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 84.05% | Validation Accuracy: 89.44%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 84.22% | Validation Accuracy: 88.47%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 84.00% | Validation Accuracy: 89.20%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 84.21% | Validation Accuracy: 89.07%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 84.30% | Validation Accuracy: 89.01%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 84.03% | Validation Accuracy: 88.22%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 83.97% | Validation Accuracy: 88.24%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 84.11% | Validation Accuracy: 89.35%
#     Fold 3 Best Val Acc: 0.8976 (89.76)%
#     Fold 3 Total Training Time: 4.21 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 81.05% | Validation Accuracy: 88.21%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 84.02% | Validation Accuracy: 88.48%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 84.13% | Validation Accuracy: 89.04%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 84.33% | Validation Accuracy: 89.33%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 84.20% | Validation Accuracy: 89.16%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 84.18% | Validation Accuracy: 89.23%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 84.12% | Validation Accuracy: 88.72%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 84.00% | Validation Accuracy: 89.16%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 84.09% | Validation Accuracy: 88.74%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 84.00% | Validation Accuracy: 89.21%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 84.14% | Validation Accuracy: 88.72%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 84.00% | Validation Accuracy: 89.45%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 84.10% | Validation Accuracy: 88.38%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 84.14% | Validation Accuracy: 89.67%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 84.14% | Validation Accuracy: 89.43%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 84.19% | Validation Accuracy: 88.50%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 84.14% | Validation Accuracy: 89.33%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 84.27% | Validation Accuracy: 89.58%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 84.25% | Validation Accuracy: 88.89%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 84.28% | Validation Accuracy: 87.46%
#     Fold 4 Best Val Acc: 0.8967 (89.67)%
#     Fold 4 Total Training Time: 4.26 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 81.50% | Validation Accuracy: 88.38%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 84.40% | Validation Accuracy: 88.23%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 84.31% | Validation Accuracy: 88.93%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 84.20% | Validation Accuracy: 88.26%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 84.28% | Validation Accuracy: 88.41%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 84.33% | Validation Accuracy: 89.03%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 84.48% | Validation Accuracy: 88.13%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 84.34% | Validation Accuracy: 89.22%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 84.26% | Validation Accuracy: 88.35%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 84.23% | Validation Accuracy: 88.42%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 84.21% | Validation Accuracy: 87.80%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 84.01% | Validation Accuracy: 88.65%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 84.33% | Validation Accuracy: 87.88%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 84.33% | Validation Accuracy: 87.20%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 84.13% | Validation Accuracy: 88.33%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 84.25% | Validation Accuracy: 89.03%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 84.24% | Validation Accuracy: 88.51%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 84.06% | Validation Accuracy: 87.88%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 84.23% | Validation Accuracy: 88.60%
# Best trial: 0. Best value: 0.8931:   5%|▌         | 1/20 [21:08<6:41:47, 1268.83s/it]
# Fold 5/5 Epoch 20/20 | Training Accuracy: 84.26% | Validation Accuracy: 88.97%
#     Fold 5 Best Val Acc: 0.8922 (89.22)%
#     Fold 5 Total Training Time: 4.13 mins.
#     All Folds Completion Total Training Time: 21.15 mins.
# Fold 1/5 Epoch 1/20 | Training Accuracy: 76.08% | Validation Accuracy: 88.08%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 85.94% | Validation Accuracy: 90.42%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 88.44% | Validation Accuracy: 91.98%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 89.83% | Validation Accuracy: 92.82%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 90.47% | Validation Accuracy: 93.38%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 91.30% | Validation Accuracy: 93.51%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 91.92% | Validation Accuracy: 93.82%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 92.12% | Validation Accuracy: 94.12%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 92.43% | Validation Accuracy: 94.02%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 92.93% | Validation Accuracy: 94.29%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 93.27% | Validation Accuracy: 94.33%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 93.45% | Validation Accuracy: 94.48%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 93.65% | Validation Accuracy: 94.65%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 93.75% | Validation Accuracy: 94.51%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 93.84% | Validation Accuracy: 94.49%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 94.09% | Validation Accuracy: 94.68%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 94.14% | Validation Accuracy: 94.67%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 94.38% | Validation Accuracy: 94.82%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 94.37% | Validation Accuracy: 94.77%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 94.62% | Validation Accuracy: 94.87%
#     Fold 1 Best Val Acc: 0.9487 (94.87)%
#     Fold 1 Total Training Time: 4.14 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 75.99% | Validation Accuracy: 88.17%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 86.00% | Validation Accuracy: 90.63%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 88.45% | Validation Accuracy: 92.33%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 89.82% | Validation Accuracy: 92.94%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 90.52% | Validation Accuracy: 93.63%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 91.30% | Validation Accuracy: 94.12%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 91.86% | Validation Accuracy: 94.36%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 92.36% | Validation Accuracy: 94.46%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 92.58% | Validation Accuracy: 94.52%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 92.71% | Validation Accuracy: 94.70%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 93.17% | Validation Accuracy: 94.95%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 93.41% | Validation Accuracy: 94.79%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 93.54% | Validation Accuracy: 95.04%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 93.91% | Validation Accuracy: 95.11%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 93.97% | Validation Accuracy: 95.08%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 93.94% | Validation Accuracy: 95.07%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 94.22% | Validation Accuracy: 95.14%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 94.29% | Validation Accuracy: 95.06%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 94.34% | Validation Accuracy: 95.08%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 94.45% | Validation Accuracy: 95.21%
#     Fold 2 Best Val Acc: 0.9521 (95.21)%
#     Fold 2 Total Training Time: 4.17 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 75.66% | Validation Accuracy: 88.50%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 86.09% | Validation Accuracy: 91.29%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 88.30% | Validation Accuracy: 92.39%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 89.40% | Validation Accuracy: 93.13%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 90.38% | Validation Accuracy: 93.50%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 90.97% | Validation Accuracy: 93.98%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 91.73% | Validation Accuracy: 94.34%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 92.06% | Validation Accuracy: 94.38%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 92.51% | Validation Accuracy: 94.81%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 92.73% | Validation Accuracy: 94.87%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 93.03% | Validation Accuracy: 95.12%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 93.16% | Validation Accuracy: 95.01%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 93.44% | Validation Accuracy: 94.92%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 93.77% | Validation Accuracy: 95.04%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 93.71% | Validation Accuracy: 95.23%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 94.00% | Validation Accuracy: 95.03%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 94.08% | Validation Accuracy: 95.17%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 94.41% | Validation Accuracy: 95.28%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 94.39% | Validation Accuracy: 95.42%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 94.50% | Validation Accuracy: 95.24%
#     Fold 3 Best Val Acc: 0.9542 (95.42)%
#     Fold 3 Total Training Time: 4.19 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 75.84% | Validation Accuracy: 88.85%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 85.87% | Validation Accuracy: 91.33%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 88.34% | Validation Accuracy: 92.64%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 89.65% | Validation Accuracy: 93.31%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 90.48% | Validation Accuracy: 93.73%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 91.29% | Validation Accuracy: 94.18%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 91.93% | Validation Accuracy: 94.27%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 92.16% | Validation Accuracy: 94.43%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 92.56% | Validation Accuracy: 94.74%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 92.82% | Validation Accuracy: 94.68%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 92.97% | Validation Accuracy: 94.82%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 93.26% | Validation Accuracy: 94.91%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 93.57% | Validation Accuracy: 95.07%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 93.73% | Validation Accuracy: 95.08%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 93.76% | Validation Accuracy: 95.07%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 93.93% | Validation Accuracy: 94.97%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 94.18% | Validation Accuracy: 95.19%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 94.30% | Validation Accuracy: 94.97%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 94.36% | Validation Accuracy: 95.12%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 94.45% | Validation Accuracy: 95.13%
#     Fold 4 Best Val Acc: 0.9519 (95.19)%
#     Fold 4 Total Training Time: 4.17 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 75.86% | Validation Accuracy: 88.45%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 85.97% | Validation Accuracy: 91.06%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 88.37% | Validation Accuracy: 92.30%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 89.69% | Validation Accuracy: 92.98%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 90.35% | Validation Accuracy: 93.45%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 91.17% | Validation Accuracy: 93.63%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 91.85% | Validation Accuracy: 93.86%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 92.09% | Validation Accuracy: 94.33%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 92.38% | Validation Accuracy: 94.13%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 92.77% | Validation Accuracy: 94.40%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 93.25% | Validation Accuracy: 94.65%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 93.39% | Validation Accuracy: 94.73%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 93.48% | Validation Accuracy: 94.95%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 93.67% | Validation Accuracy: 94.76%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 93.86% | Validation Accuracy: 94.83%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 94.15% | Validation Accuracy: 94.87%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 94.15% | Validation Accuracy: 95.10%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 94.26% | Validation Accuracy: 95.19%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 94.30% | Validation Accuracy: 95.07%
# Best trial: 1. Best value: 0.95175:  10%|█         | 2/20 [42:03<6:18:08, 1260.48s/it]
# Fold 5/5 Epoch 20/20 | Training Accuracy: 94.68% | Validation Accuracy: 95.00%
#     Fold 5 Best Val Acc: 0.9519 (95.19)%
#     Fold 5 Total Training Time: 4.23 mins.
#     All Folds Completion Total Training Time: 20.91 mins.
# Fold 1/5 Epoch 1/20 | Training Accuracy: 71.98% | Validation Accuracy: 78.62%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 72.85% | Validation Accuracy: 76.60%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 73.09% | Validation Accuracy: 78.66%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 73.00% | Validation Accuracy: 75.03%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 72.99% | Validation Accuracy: 77.53%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 72.84% | Validation Accuracy: 76.59%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 73.22% | Validation Accuracy: 77.26%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 72.90% | Validation Accuracy: 76.21%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 72.88% | Validation Accuracy: 77.81%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 72.97% | Validation Accuracy: 79.23%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 72.95% | Validation Accuracy: 79.53%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 73.21% | Validation Accuracy: 79.10%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 73.05% | Validation Accuracy: 77.36%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 72.95% | Validation Accuracy: 78.42%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 73.42% | Validation Accuracy: 77.08%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 73.01% | Validation Accuracy: 77.98%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 72.79% | Validation Accuracy: 77.92%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 73.13% | Validation Accuracy: 78.66%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 72.84% | Validation Accuracy: 78.77%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 73.01% | Validation Accuracy: 76.21%
#     Fold 1 Best Val Acc: 0.7953 (79.53)%
#     Fold 1 Total Training Time: 4.17 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 71.80% | Validation Accuracy: 79.07%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 72.86% | Validation Accuracy: 80.81%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 72.97% | Validation Accuracy: 79.83%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 72.93% | Validation Accuracy: 81.87%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 72.76% | Validation Accuracy: 78.96%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 73.07% | Validation Accuracy: 80.96%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 72.82% | Validation Accuracy: 79.30%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 73.05% | Validation Accuracy: 78.21%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 72.95% | Validation Accuracy: 75.94%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 72.81% | Validation Accuracy: 78.98%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 73.05% | Validation Accuracy: 76.47%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 73.10% | Validation Accuracy: 77.18%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 72.69% | Validation Accuracy: 79.26%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 73.09% | Validation Accuracy: 76.48%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 73.13% | Validation Accuracy: 79.16%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 72.89% | Validation Accuracy: 79.10%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 72.50% | Validation Accuracy: 79.06%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 72.73% | Validation Accuracy: 80.54%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 72.79% | Validation Accuracy: 78.40%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 72.84% | Validation Accuracy: 76.63%
#     Fold 2 Best Val Acc: 0.8187 (81.87)%
#     Fold 2 Total Training Time: 4.23 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 71.84% | Validation Accuracy: 79.38%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 73.15% | Validation Accuracy: 80.12%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 73.26% | Validation Accuracy: 77.12%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 72.93% | Validation Accuracy: 78.08%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 72.93% | Validation Accuracy: 80.59%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 72.97% | Validation Accuracy: 78.80%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 72.94% | Validation Accuracy: 74.14%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 72.98% | Validation Accuracy: 79.38%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 72.86% | Validation Accuracy: 80.78%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 72.86% | Validation Accuracy: 79.27%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 72.99% | Validation Accuracy: 80.77%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 73.10% | Validation Accuracy: 79.26%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 72.83% | Validation Accuracy: 75.62%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 73.20% | Validation Accuracy: 79.59%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 72.76% | Validation Accuracy: 73.17%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 72.92% | Validation Accuracy: 75.22%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 72.82% | Validation Accuracy: 76.57%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 72.92% | Validation Accuracy: 76.99%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 72.82% | Validation Accuracy: 80.85%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 73.04% | Validation Accuracy: 78.83%
#     Fold 3 Best Val Acc: 0.8085 (80.85)%
#     Fold 3 Total Training Time: 4.19 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 72.03% | Validation Accuracy: 77.67%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 73.00% | Validation Accuracy: 79.64%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 72.92% | Validation Accuracy: 77.31%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 73.10% | Validation Accuracy: 77.53%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 72.80% | Validation Accuracy: 77.55%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 72.81% | Validation Accuracy: 79.17%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 72.72% | Validation Accuracy: 80.90%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 72.64% | Validation Accuracy: 81.06%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 72.86% | Validation Accuracy: 76.78%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 72.46% | Validation Accuracy: 78.12%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 73.06% | Validation Accuracy: 76.83%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 72.91% | Validation Accuracy: 79.18%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 72.89% | Validation Accuracy: 75.45%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 72.79% | Validation Accuracy: 76.22%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 73.04% | Validation Accuracy: 79.90%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 72.75% | Validation Accuracy: 76.98%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 72.80% | Validation Accuracy: 77.60%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 72.92% | Validation Accuracy: 74.66%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 72.81% | Validation Accuracy: 79.40%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 72.86% | Validation Accuracy: 73.17%
#     Fold 4 Best Val Acc: 0.8106 (81.06)%
#     Fold 4 Total Training Time: 4.19 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 72.10% | Validation Accuracy: 77.15%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 73.16% | Validation Accuracy: 79.90%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 72.72% | Validation Accuracy: 77.73%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 72.60% | Validation Accuracy: 80.47%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 73.09% | Validation Accuracy: 79.97%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 72.67% | Validation Accuracy: 78.86%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 72.86% | Validation Accuracy: 79.86%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 72.79% | Validation Accuracy: 69.59%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 72.75% | Validation Accuracy: 74.93%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 72.98% | Validation Accuracy: 77.90%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 72.67% | Validation Accuracy: 79.70%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 72.72% | Validation Accuracy: 79.50%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 72.65% | Validation Accuracy: 76.83%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 72.96% | Validation Accuracy: 79.27%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 72.85% | Validation Accuracy: 70.33%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 72.97% | Validation Accuracy: 80.27%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 72.95% | Validation Accuracy: 77.84%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 72.94% | Validation Accuracy: 79.87%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 72.90% | Validation Accuracy: 76.28%
# Best trial: 1. Best value: 0.95175:  15%|█▌        | 3/20 [1:03:05<5:57:17, 1261.06s/it]
# Fold 5/5 Epoch 20/20 | Training Accuracy: 72.76% | Validation Accuracy: 78.38%
#     Fold 5 Best Val Acc: 0.8047 (80.47)%
#     Fold 5 Total Training Time: 4.26 mins.
#     All Folds Completion Total Training Time: 21.03 mins.
# Fold 1/5 Epoch 1/20 | Training Accuracy: 68.30% | Validation Accuracy: 74.95%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 69.73% | Validation Accuracy: 73.78%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 69.95% | Validation Accuracy: 77.92%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 69.95% | Validation Accuracy: 70.50%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 69.65% | Validation Accuracy: 73.42%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 69.67% | Validation Accuracy: 74.07%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 69.78% | Validation Accuracy: 69.23%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 69.81% | Validation Accuracy: 75.76%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 69.21% | Validation Accuracy: 75.29%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 69.67% | Validation Accuracy: 75.46%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 69.51% | Validation Accuracy: 77.50%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 69.46% | Validation Accuracy: 73.35%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 69.70% | Validation Accuracy: 77.04%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 69.67% | Validation Accuracy: 77.51%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 69.87% | Validation Accuracy: 68.13%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 69.52% | Validation Accuracy: 74.45%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 69.56% | Validation Accuracy: 74.25%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 69.86% | Validation Accuracy: 72.76%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 69.72% | Validation Accuracy: 74.57%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 69.89% | Validation Accuracy: 76.48%
#     Fold 1 Best Val Acc: 0.7792 (77.92)%
#     Fold 1 Total Training Time: 4.20 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 68.21% | Validation Accuracy: 74.67%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 69.40% | Validation Accuracy: 74.67%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 69.97% | Validation Accuracy: 68.67%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 69.84% | Validation Accuracy: 78.86%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 69.46% | Validation Accuracy: 73.06%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 69.82% | Validation Accuracy: 75.45%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 69.38% | Validation Accuracy: 75.95%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 69.81% | Validation Accuracy: 72.44%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 69.85% | Validation Accuracy: 70.62%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 69.71% | Validation Accuracy: 73.38%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 69.45% | Validation Accuracy: 73.37%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 69.79% | Validation Accuracy: 77.04%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 69.92% | Validation Accuracy: 72.48%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 69.64% | Validation Accuracy: 73.77%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 69.81% | Validation Accuracy: 73.27%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 69.81% | Validation Accuracy: 75.91%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 69.66% | Validation Accuracy: 75.27%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 69.80% | Validation Accuracy: 71.92%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 69.84% | Validation Accuracy: 73.82%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 69.57% | Validation Accuracy: 71.19%
#     Fold 2 Best Val Acc: 0.7886 (78.86)%
#     Fold 2 Total Training Time: 4.14 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 68.12% | Validation Accuracy: 74.17%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 69.79% | Validation Accuracy: 72.97%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 69.77% | Validation Accuracy: 69.25%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 69.60% | Validation Accuracy: 76.49%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 69.55% | Validation Accuracy: 79.64%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 69.66% | Validation Accuracy: 77.19%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 69.42% | Validation Accuracy: 75.50%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 69.80% | Validation Accuracy: 77.27%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 69.35% | Validation Accuracy: 75.10%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 69.35% | Validation Accuracy: 70.84%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 69.51% | Validation Accuracy: 74.96%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 69.81% | Validation Accuracy: 76.28%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 69.41% | Validation Accuracy: 75.82%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 69.66% | Validation Accuracy: 70.91%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 69.39% | Validation Accuracy: 67.13%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 69.68% | Validation Accuracy: 73.37%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 69.80% | Validation Accuracy: 75.09%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 69.35% | Validation Accuracy: 73.52%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 69.11% | Validation Accuracy: 74.29%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 69.55% | Validation Accuracy: 74.81%
#     Fold 3 Best Val Acc: 0.7964 (79.64)%
#     Fold 3 Total Training Time: 4.21 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 67.90% | Validation Accuracy: 72.96%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 69.93% | Validation Accuracy: 76.25%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 69.57% | Validation Accuracy: 67.30%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 69.63% | Validation Accuracy: 70.33%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 69.45% | Validation Accuracy: 76.06%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 69.61% | Validation Accuracy: 75.81%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 69.67% | Validation Accuracy: 76.60%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 69.26% | Validation Accuracy: 77.47%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 69.81% | Validation Accuracy: 74.34%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 69.55% | Validation Accuracy: 66.40%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 69.33% | Validation Accuracy: 77.07%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 69.58% | Validation Accuracy: 70.94%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 69.70% | Validation Accuracy: 71.82%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 69.57% | Validation Accuracy: 78.19%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 69.48% | Validation Accuracy: 75.56%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 69.46% | Validation Accuracy: 78.40%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 69.43% | Validation Accuracy: 77.13%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 69.59% | Validation Accuracy: 70.36%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 69.66% | Validation Accuracy: 73.78%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 69.18% | Validation Accuracy: 75.48%
#     Fold 4 Best Val Acc: 0.7840 (78.40)%
#     Fold 4 Total Training Time: 4.20 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 68.33% | Validation Accuracy: 76.46%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 69.46% | Validation Accuracy: 71.95%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 69.51% | Validation Accuracy: 72.64%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 69.72% | Validation Accuracy: 76.37%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 69.48% | Validation Accuracy: 73.51%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 69.50% | Validation Accuracy: 51.46%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 69.76% | Validation Accuracy: 76.33%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 69.45% | Validation Accuracy: 73.43%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 69.30% | Validation Accuracy: 76.48%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 69.30% | Validation Accuracy: 75.83%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 69.50% | Validation Accuracy: 69.59%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 69.82% | Validation Accuracy: 76.14%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 69.51% | Validation Accuracy: 71.03%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 69.67% | Validation Accuracy: 75.32%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 69.10% | Validation Accuracy: 73.76%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 69.83% | Validation Accuracy: 74.65%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 69.56% | Validation Accuracy: 59.69%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 69.24% | Validation Accuracy: 75.74%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 69.53% | Validation Accuracy: 76.41%
# Best trial: 1. Best value: 0.95175:  20%|██        | 4/20 [1:24:04<5:36:02, 1260.18s/it]
# Fold 5/5 Epoch 20/20 | Training Accuracy: 69.30% | Validation Accuracy: 75.67%
#     Fold 5 Best Val Acc: 0.7648 (76.48)%
#     Fold 5 Total Training Time: 4.24 mins.
#     All Folds Completion Total Training Time: 20.98 mins.
# Fold 1/5 Epoch 1/20 | Training Accuracy: 84.14% | Validation Accuracy: 91.46%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 89.40% | Validation Accuracy: 92.62%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 91.11% | Validation Accuracy: 93.51%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 91.67% | Validation Accuracy: 94.00%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 92.23% | Validation Accuracy: 94.00%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 92.63% | Validation Accuracy: 94.25%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 92.87% | Validation Accuracy: 94.28%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 92.77% | Validation Accuracy: 94.52%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 93.05% | Validation Accuracy: 94.83%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 93.56% | Validation Accuracy: 94.68%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 93.60% | Validation Accuracy: 94.85%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 93.58% | Validation Accuracy: 94.83%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 93.69% | Validation Accuracy: 95.03%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 93.84% | Validation Accuracy: 94.67%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 94.04% | Validation Accuracy: 94.49%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 93.99% | Validation Accuracy: 94.94%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 94.18% | Validation Accuracy: 94.83%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 94.19% | Validation Accuracy: 94.62%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 94.04% | Validation Accuracy: 94.77%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 94.29% | Validation Accuracy: 94.68%
#     Fold 1 Best Val Acc: 0.9503 (95.03)%
#     Fold 1 Total Training Time: 4.26 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 83.95% | Validation Accuracy: 91.94%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 89.52% | Validation Accuracy: 93.28%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 91.10% | Validation Accuracy: 94.13%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 91.95% | Validation Accuracy: 94.45%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 92.35% | Validation Accuracy: 94.96%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 92.81% | Validation Accuracy: 95.11%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 93.14% | Validation Accuracy: 95.06%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 93.45% | Validation Accuracy: 94.88%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 93.38% | Validation Accuracy: 95.36%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 93.60% | Validation Accuracy: 94.88%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 93.95% | Validation Accuracy: 95.09%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 93.78% | Validation Accuracy: 95.20%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 93.91% | Validation Accuracy: 95.30%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 93.94% | Validation Accuracy: 95.08%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 94.11% | Validation Accuracy: 95.07%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 94.05% | Validation Accuracy: 95.34%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 94.15% | Validation Accuracy: 95.23%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 94.12% | Validation Accuracy: 95.06%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 94.14% | Validation Accuracy: 95.11%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 94.24% | Validation Accuracy: 95.23%
#     Fold 2 Best Val Acc: 0.9536 (95.36)%
#     Fold 2 Total Training Time: 4.18 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 83.83% | Validation Accuracy: 92.00%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 89.53% | Validation Accuracy: 93.45%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 91.00% | Validation Accuracy: 94.26%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 91.73% | Validation Accuracy: 94.39%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 92.47% | Validation Accuracy: 94.38%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 92.60% | Validation Accuracy: 94.53%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 93.03% | Validation Accuracy: 94.83%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 93.14% | Validation Accuracy: 95.17%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 93.31% | Validation Accuracy: 94.69%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 93.42% | Validation Accuracy: 95.00%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 93.47% | Validation Accuracy: 95.17%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 93.74% | Validation Accuracy: 95.17%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 93.73% | Validation Accuracy: 95.17%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 93.92% | Validation Accuracy: 95.30%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 93.98% | Validation Accuracy: 95.27%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 93.97% | Validation Accuracy: 95.11%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 93.92% | Validation Accuracy: 95.28%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 94.19% | Validation Accuracy: 95.26%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 94.21% | Validation Accuracy: 95.23%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 94.20% | Validation Accuracy: 95.35%
#     Fold 3 Best Val Acc: 0.9535 (95.35)%
#     Fold 3 Total Training Time: 4.26 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 83.77% | Validation Accuracy: 92.28%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 89.32% | Validation Accuracy: 93.46%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 90.80% | Validation Accuracy: 94.47%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 91.65% | Validation Accuracy: 94.65%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 92.19% | Validation Accuracy: 94.55%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 92.52% | Validation Accuracy: 94.88%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 92.65% | Validation Accuracy: 95.16%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 93.02% | Validation Accuracy: 94.80%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 93.18% | Validation Accuracy: 94.99%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 93.35% | Validation Accuracy: 95.03%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 93.48% | Validation Accuracy: 94.88%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 93.55% | Validation Accuracy: 95.22%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 93.74% | Validation Accuracy: 95.14%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 93.77% | Validation Accuracy: 95.22%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 93.72% | Validation Accuracy: 95.45%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 93.85% | Validation Accuracy: 95.18%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 94.04% | Validation Accuracy: 95.53%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 94.11% | Validation Accuracy: 95.13%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 94.29% | Validation Accuracy: 95.41%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 94.21% | Validation Accuracy: 95.16%
#     Fold 4 Best Val Acc: 0.9553 (95.53)%
#     Fold 4 Total Training Time: 4.22 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 84.06% | Validation Accuracy: 92.03%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 89.74% | Validation Accuracy: 93.53%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 90.96% | Validation Accuracy: 94.26%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 92.02% | Validation Accuracy: 94.44%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 92.24% | Validation Accuracy: 94.38%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 92.54% | Validation Accuracy: 94.49%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 92.92% | Validation Accuracy: 94.92%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 93.00% | Validation Accuracy: 94.83%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 93.30% | Validation Accuracy: 94.62%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 93.51% | Validation Accuracy: 94.76%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 93.75% | Validation Accuracy: 94.86%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 93.64% | Validation Accuracy: 94.95%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 93.89% | Validation Accuracy: 95.25%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 93.82% | Validation Accuracy: 94.92%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 93.95% | Validation Accuracy: 95.00%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 94.11% | Validation Accuracy: 94.77%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 94.05% | Validation Accuracy: 94.95%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 94.15% | Validation Accuracy: 94.93%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 94.17% | Validation Accuracy: 95.02%
# Best trial: 4. Best value: 0.95305:  25%|██▌       | 5/20 [1:45:14<5:16:00, 1264.01s/it]
# Fold 5/5 Epoch 20/20 | Training Accuracy: 94.25% | Validation Accuracy: 94.99%
#     Fold 5 Best Val Acc: 0.9525 (95.25)%
#     Fold 5 Total Training Time: 4.26 mins.
#     All Folds Completion Total Training Time: 21.18 mins.
# Fold 1/5 Epoch 1/20 | Training Accuracy: 83.07% | Validation Accuracy: 90.64%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 88.05% | Validation Accuracy: 91.20%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 89.29% | Validation Accuracy: 92.29%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 89.44% | Validation Accuracy: 92.27%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 89.62% | Validation Accuracy: 92.48%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 89.69% | Validation Accuracy: 92.56%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 89.91% | Validation Accuracy: 92.33%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 89.63% | Validation Accuracy: 92.75%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 89.85% | Validation Accuracy: 92.67%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 90.04% | Validation Accuracy: 92.96%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 89.88% | Validation Accuracy: 92.78%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 89.83% | Validation Accuracy: 92.94%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 90.06% | Validation Accuracy: 93.05%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 89.93% | Validation Accuracy: 93.00%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 90.06% | Validation Accuracy: 92.23%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 90.01% | Validation Accuracy: 92.83%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 89.95% | Validation Accuracy: 92.88%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 89.84% | Validation Accuracy: 92.61%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 89.77% | Validation Accuracy: 92.30%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 89.95% | Validation Accuracy: 92.56%
#     Fold 1 Best Val Acc: 0.9305 (93.05)%
#     Fold 1 Total Training Time: 4.17 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 83.23% | Validation Accuracy: 90.52%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 87.96% | Validation Accuracy: 91.65%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 89.09% | Validation Accuracy: 92.48%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 89.44% | Validation Accuracy: 92.62%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 89.56% | Validation Accuracy: 92.81%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 89.78% | Validation Accuracy: 93.42%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 89.66% | Validation Accuracy: 92.97%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 89.92% | Validation Accuracy: 93.08%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 89.75% | Validation Accuracy: 92.91%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 89.96% | Validation Accuracy: 93.08%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 89.95% | Validation Accuracy: 92.78%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 89.95% | Validation Accuracy: 93.01%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 89.93% | Validation Accuracy: 93.73%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 89.96% | Validation Accuracy: 92.47%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 89.88% | Validation Accuracy: 93.01%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 89.89% | Validation Accuracy: 93.33%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 89.79% | Validation Accuracy: 92.97%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 89.97% | Validation Accuracy: 92.86%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 89.66% | Validation Accuracy: 93.30%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 89.83% | Validation Accuracy: 93.26%
#     Fold 2 Best Val Acc: 0.9373 (93.73)%
#     Fold 2 Total Training Time: 4.14 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 82.89% | Validation Accuracy: 91.03%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 88.19% | Validation Accuracy: 92.00%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 88.83% | Validation Accuracy: 92.92%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 89.20% | Validation Accuracy: 92.92%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 89.56% | Validation Accuracy: 92.51%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 89.51% | Validation Accuracy: 93.33%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 89.70% | Validation Accuracy: 93.08%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 89.65% | Validation Accuracy: 93.40%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 89.48% | Validation Accuracy: 92.88%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 89.61% | Validation Accuracy: 92.82%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 89.83% | Validation Accuracy: 92.88%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 89.82% | Validation Accuracy: 93.64%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 89.80% | Validation Accuracy: 92.97%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 89.81% | Validation Accuracy: 93.50%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 89.98% | Validation Accuracy: 93.13%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 89.84% | Validation Accuracy: 93.44%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 89.89% | Validation Accuracy: 93.39%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 89.85% | Validation Accuracy: 93.40%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 89.98% | Validation Accuracy: 93.54%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 89.83% | Validation Accuracy: 93.59%
#     Fold 3 Best Val Acc: 0.9364 (93.64)%
#     Fold 3 Total Training Time: 4.25 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 82.88% | Validation Accuracy: 91.33%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 88.00% | Validation Accuracy: 92.22%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 88.86% | Validation Accuracy: 92.60%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 89.37% | Validation Accuracy: 93.05%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 89.35% | Validation Accuracy: 93.10%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 89.65% | Validation Accuracy: 93.07%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 89.67% | Validation Accuracy: 93.16%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 89.58% | Validation Accuracy: 93.14%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 89.78% | Validation Accuracy: 92.99%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 89.75% | Validation Accuracy: 93.15%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 89.87% | Validation Accuracy: 93.17%
# ...
# Fold 1/5 Epoch 15/20 | Training Accuracy: 86.94% | Validation Accuracy: 89.84%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 86.80% | Validation Accuracy: 91.11%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 86.93% | Validation Accuracy: 90.68%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 86.96% | Validation Accuracy: 91.03%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 86.77% | Validation Accuracy: 91.17%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 87.03% | Validation Accuracy: 91.17%
#     Fold 1 Best Val Acc: 0.9156 (91.56)%
#     Fold 1 Total Training Time: 4.21 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 82.40% | Validation Accuracy: 89.70%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 85.95% | Validation Accuracy: 90.36%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 86.29% | Validation Accuracy: 90.65%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 86.73% | Validation Accuracy: 90.54%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 86.71% | Validation Accuracy: 91.42%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 86.62% | Validation Accuracy: 90.60%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 86.77% | Validation Accuracy: 91.07%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 87.10% | Validation Accuracy: 90.85%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 86.84% | Validation Accuracy: 91.15%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 86.83% | Validation Accuracy: 91.38%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 86.84% | Validation Accuracy: 91.33%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 87.08% | Validation Accuracy: 91.15%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 86.93% | Validation Accuracy: 91.35%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 87.11% | Validation Accuracy: 91.50%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 86.90% | Validation Accuracy: 91.39%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 87.03% | Validation Accuracy: 91.42%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 87.14% | Validation Accuracy: 91.22%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 86.85% | Validation Accuracy: 90.34%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 86.67% | Validation Accuracy: 90.83%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 86.73% | Validation Accuracy: 91.70%
#     Fold 2 Best Val Acc: 0.9170 (91.70)%
#     Fold 2 Total Training Time: 4.09 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 82.09% | Validation Accuracy: 88.66%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 85.84% | Validation Accuracy: 91.07%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 86.26% | Validation Accuracy: 90.67%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 86.40% | Validation Accuracy: 91.14%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 86.72% | Validation Accuracy: 91.62%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 86.60% | Validation Accuracy: 91.62%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 86.71% | Validation Accuracy: 90.53%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 86.55% | Validation Accuracy: 90.86%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 86.44% | Validation Accuracy: 90.56%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 86.55% | Validation Accuracy: 91.44%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 86.75% | Validation Accuracy: 91.15%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 86.82% | Validation Accuracy: 91.92%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 86.83% | Validation Accuracy: 90.69%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 86.62% | Validation Accuracy: 90.83%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 86.67% | Validation Accuracy: 91.25%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 86.68% | Validation Accuracy: 91.27%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 86.90% | Validation Accuracy: 91.92%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 86.95% | Validation Accuracy: 91.74%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 86.86% | Validation Accuracy: 91.40%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 86.77% | Validation Accuracy: 91.12%
#     Fold 3 Best Val Acc: 0.9193 (91.92)%
#     Fold 3 Total Training Time: 4.20 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 82.21% | Validation Accuracy: 89.89%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 85.73% | Validation Accuracy: 90.20%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 86.24% | Validation Accuracy: 91.22%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 86.63% | Validation Accuracy: 91.71%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 86.47% | Validation Accuracy: 90.85%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 86.66% | Validation Accuracy: 91.48%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 86.63% | Validation Accuracy: 92.32%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 86.51% | Validation Accuracy: 91.24%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 86.69% | Validation Accuracy: 91.55%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 86.64% | Validation Accuracy: 92.27%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 86.62% | Validation Accuracy: 90.92%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 86.72% | Validation Accuracy: 91.34%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 86.81% | Validation Accuracy: 91.07%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 86.82% | Validation Accuracy: 91.88%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 86.90% | Validation Accuracy: 91.69%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 86.67% | Validation Accuracy: 91.39%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 86.54% | Validation Accuracy: 91.18%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 86.80% | Validation Accuracy: 91.67%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 86.88% | Validation Accuracy: 91.48%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 86.58% | Validation Accuracy: 91.50%
#     Fold 4 Best Val Acc: 0.9232 (92.32)%
#     Fold 4 Total Training Time: 4.17 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 82.53% | Validation Accuracy: 90.28%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 86.03% | Validation Accuracy: 90.26%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 86.35% | Validation Accuracy: 90.90%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 86.80% | Validation Accuracy: 90.80%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 86.70% | Validation Accuracy: 91.21%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 86.45% | Validation Accuracy: 91.33%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 86.67% | Validation Accuracy: 90.92%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 86.64% | Validation Accuracy: 91.42%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 86.95% | Validation Accuracy: 91.13%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 86.97% | Validation Accuracy: 90.92%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 87.00% | Validation Accuracy: 91.32%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 86.96% | Validation Accuracy: 91.62%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 86.89% | Validation Accuracy: 90.93%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 86.87% | Validation Accuracy: 91.53%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 86.78% | Validation Accuracy: 90.88%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 86.90% | Validation Accuracy: 91.49%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 86.84% | Validation Accuracy: 90.51%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 87.01% | Validation Accuracy: 90.98%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 87.02% | Validation Accuracy: 91.43%
# Best trial: 14. Best value: 0.9559:  95%|█████████▌| 19/20 [6:43:29<21:27, 1287.93s/it]
# Fold 5/5 Epoch 20/20 | Training Accuracy: 86.97% | Validation Accuracy: 91.96%
#     Fold 5 Best Val Acc: 0.9196 (91.96)%
#     Fold 5 Total Training Time: 4.20 mins.
#     All Folds Completion Total Training Time: 20.87 mins.
# Fold 1/5 Epoch 1/20 | Training Accuracy: 47.08% | Validation Accuracy: 55.04%
# Fold 1/5 Epoch 2/20 | Training Accuracy: 46.75% | Validation Accuracy: 27.71%
# Fold 1/5 Epoch 3/20 | Training Accuracy: 46.82% | Validation Accuracy: 41.77%
# Fold 1/5 Epoch 4/20 | Training Accuracy: 47.65% | Validation Accuracy: 48.54%
# Fold 1/5 Epoch 5/20 | Training Accuracy: 47.97% | Validation Accuracy: 50.24%
# Fold 1/5 Epoch 6/20 | Training Accuracy: 47.47% | Validation Accuracy: 45.36%
# Fold 1/5 Epoch 7/20 | Training Accuracy: 47.63% | Validation Accuracy: 54.08%
# Fold 1/5 Epoch 8/20 | Training Accuracy: 45.68% | Validation Accuracy: 61.78%
# Fold 1/5 Epoch 9/20 | Training Accuracy: 46.85% | Validation Accuracy: 42.48%
# Fold 1/5 Epoch 10/20 | Training Accuracy: 47.86% | Validation Accuracy: 52.10%
# Fold 1/5 Epoch 11/20 | Training Accuracy: 46.01% | Validation Accuracy: 53.51%
# Fold 1/5 Epoch 12/20 | Training Accuracy: 47.19% | Validation Accuracy: 49.73%
# Fold 1/5 Epoch 13/20 | Training Accuracy: 47.52% | Validation Accuracy: 49.63%
# Fold 1/5 Epoch 14/20 | Training Accuracy: 46.79% | Validation Accuracy: 50.12%
# Fold 1/5 Epoch 15/20 | Training Accuracy: 46.74% | Validation Accuracy: 33.48%
# Fold 1/5 Epoch 16/20 | Training Accuracy: 46.73% | Validation Accuracy: 47.48%
# Fold 1/5 Epoch 17/20 | Training Accuracy: 47.38% | Validation Accuracy: 55.18%
# Fold 1/5 Epoch 18/20 | Training Accuracy: 47.25% | Validation Accuracy: 46.13%
# Fold 1/5 Epoch 19/20 | Training Accuracy: 45.75% | Validation Accuracy: 52.76%
# Fold 1/5 Epoch 20/20 | Training Accuracy: 47.90% | Validation Accuracy: 53.15%
#     Fold 1 Best Val Acc: 0.6178 (61.78)%
#     Fold 1 Total Training Time: 4.27 mins.
# Fold 2/5 Epoch 1/20 | Training Accuracy: 47.18% | Validation Accuracy: 49.98%
# Fold 2/5 Epoch 2/20 | Training Accuracy: 47.14% | Validation Accuracy: 50.57%
# Fold 2/5 Epoch 3/20 | Training Accuracy: 47.40% | Validation Accuracy: 51.21%
# Fold 2/5 Epoch 4/20 | Training Accuracy: 47.40% | Validation Accuracy: 56.78%
# Fold 2/5 Epoch 5/20 | Training Accuracy: 46.95% | Validation Accuracy: 52.28%
# Fold 2/5 Epoch 6/20 | Training Accuracy: 47.84% | Validation Accuracy: 54.83%
# Fold 2/5 Epoch 7/20 | Training Accuracy: 47.09% | Validation Accuracy: 56.24%
# Fold 2/5 Epoch 8/20 | Training Accuracy: 48.35% | Validation Accuracy: 49.73%
# Fold 2/5 Epoch 9/20 | Training Accuracy: 47.74% | Validation Accuracy: 33.96%
# Fold 2/5 Epoch 10/20 | Training Accuracy: 48.94% | Validation Accuracy: 29.51%
# Fold 2/5 Epoch 11/20 | Training Accuracy: 47.85% | Validation Accuracy: 54.33%
# Fold 2/5 Epoch 12/20 | Training Accuracy: 47.56% | Validation Accuracy: 44.63%
# Fold 2/5 Epoch 13/20 | Training Accuracy: 47.32% | Validation Accuracy: 54.67%
# Fold 2/5 Epoch 14/20 | Training Accuracy: 47.24% | Validation Accuracy: 59.45%
# Fold 2/5 Epoch 15/20 | Training Accuracy: 48.01% | Validation Accuracy: 48.77%
# Fold 2/5 Epoch 16/20 | Training Accuracy: 47.05% | Validation Accuracy: 34.40%
# Fold 2/5 Epoch 17/20 | Training Accuracy: 47.55% | Validation Accuracy: 38.03%
# Fold 2/5 Epoch 18/20 | Training Accuracy: 46.75% | Validation Accuracy: 52.31%
# Fold 2/5 Epoch 19/20 | Training Accuracy: 47.23% | Validation Accuracy: 46.00%
# Fold 2/5 Epoch 20/20 | Training Accuracy: 46.19% | Validation Accuracy: 51.93%
#     Fold 2 Best Val Acc: 0.5945 (59.45)%
#     Fold 2 Total Training Time: 4.17 mins.
# Fold 3/5 Epoch 1/20 | Training Accuracy: 46.18% | Validation Accuracy: 53.37%
# Fold 3/5 Epoch 2/20 | Training Accuracy: 47.47% | Validation Accuracy: 62.43%
# Fold 3/5 Epoch 3/20 | Training Accuracy: 46.86% | Validation Accuracy: 54.19%
# Fold 3/5 Epoch 4/20 | Training Accuracy: 47.65% | Validation Accuracy: 49.19%
# Fold 3/5 Epoch 5/20 | Training Accuracy: 47.33% | Validation Accuracy: 47.11%
# Fold 3/5 Epoch 6/20 | Training Accuracy: 46.90% | Validation Accuracy: 51.57%
# Fold 3/5 Epoch 7/20 | Training Accuracy: 47.09% | Validation Accuracy: 39.20%
# Fold 3/5 Epoch 8/20 | Training Accuracy: 46.99% | Validation Accuracy: 50.48%
# Fold 3/5 Epoch 9/20 | Training Accuracy: 47.37% | Validation Accuracy: 44.42%
# Fold 3/5 Epoch 10/20 | Training Accuracy: 47.58% | Validation Accuracy: 57.55%
# Fold 3/5 Epoch 11/20 | Training Accuracy: 47.78% | Validation Accuracy: 55.99%
# Fold 3/5 Epoch 12/20 | Training Accuracy: 47.10% | Validation Accuracy: 49.28%
# Fold 3/5 Epoch 13/20 | Training Accuracy: 46.67% | Validation Accuracy: 41.53%
# Fold 3/5 Epoch 14/20 | Training Accuracy: 47.12% | Validation Accuracy: 53.09%
# Fold 3/5 Epoch 15/20 | Training Accuracy: 47.41% | Validation Accuracy: 48.73%
# Fold 3/5 Epoch 16/20 | Training Accuracy: 47.71% | Validation Accuracy: 60.56%
# Fold 3/5 Epoch 17/20 | Training Accuracy: 47.03% | Validation Accuracy: 49.75%
# Fold 3/5 Epoch 18/20 | Training Accuracy: 47.26% | Validation Accuracy: 59.94%
# Fold 3/5 Epoch 19/20 | Training Accuracy: 47.04% | Validation Accuracy: 52.28%
# Fold 3/5 Epoch 20/20 | Training Accuracy: 47.84% | Validation Accuracy: 39.62%
#     Fold 3 Best Val Acc: 0.6243 (62.43)%
#     Fold 3 Total Training Time: 4.04 mins.
# Fold 4/5 Epoch 1/20 | Training Accuracy: 46.86% | Validation Accuracy: 35.38%
# Fold 4/5 Epoch 2/20 | Training Accuracy: 46.44% | Validation Accuracy: 45.88%
# Fold 4/5 Epoch 3/20 | Training Accuracy: 47.27% | Validation Accuracy: 47.62%
# Fold 4/5 Epoch 4/20 | Training Accuracy: 46.94% | Validation Accuracy: 59.16%
# Fold 4/5 Epoch 5/20 | Training Accuracy: 46.80% | Validation Accuracy: 43.68%
# Fold 4/5 Epoch 6/20 | Training Accuracy: 47.66% | Validation Accuracy: 59.02%
# Fold 4/5 Epoch 7/20 | Training Accuracy: 46.49% | Validation Accuracy: 57.07%
# Fold 4/5 Epoch 8/20 | Training Accuracy: 46.95% | Validation Accuracy: 48.36%
# Fold 4/5 Epoch 9/20 | Training Accuracy: 47.31% | Validation Accuracy: 32.77%
# Fold 4/5 Epoch 10/20 | Training Accuracy: 46.42% | Validation Accuracy: 51.42%
# Fold 4/5 Epoch 11/20 | Training Accuracy: 46.73% | Validation Accuracy: 49.23%
# Fold 4/5 Epoch 12/20 | Training Accuracy: 46.79% | Validation Accuracy: 44.69%
# Fold 4/5 Epoch 13/20 | Training Accuracy: 48.19% | Validation Accuracy: 51.93%
# Fold 4/5 Epoch 14/20 | Training Accuracy: 47.87% | Validation Accuracy: 50.88%
# Fold 4/5 Epoch 15/20 | Training Accuracy: 47.63% | Validation Accuracy: 55.89%
# Fold 4/5 Epoch 16/20 | Training Accuracy: 47.27% | Validation Accuracy: 39.25%
# Fold 4/5 Epoch 17/20 | Training Accuracy: 46.76% | Validation Accuracy: 54.51%
# Fold 4/5 Epoch 18/20 | Training Accuracy: 48.11% | Validation Accuracy: 50.03%
# Fold 4/5 Epoch 19/20 | Training Accuracy: 47.26% | Validation Accuracy: 62.28%
# Fold 4/5 Epoch 20/20 | Training Accuracy: 48.26% | Validation Accuracy: 54.71%
#     Fold 4 Best Val Acc: 0.6228 (62.28)%
#     Fold 4 Total Training Time: 4.10 mins.
# Fold 5/5 Epoch 1/20 | Training Accuracy: 45.89% | Validation Accuracy: 53.88%
# Fold 5/5 Epoch 2/20 | Training Accuracy: 46.94% | Validation Accuracy: 41.08%
# Fold 5/5 Epoch 3/20 | Training Accuracy: 47.12% | Validation Accuracy: 48.30%
# Fold 5/5 Epoch 4/20 | Training Accuracy: 47.81% | Validation Accuracy: 55.46%
# Fold 5/5 Epoch 5/20 | Training Accuracy: 46.99% | Validation Accuracy: 49.99%
# Fold 5/5 Epoch 6/20 | Training Accuracy: 47.00% | Validation Accuracy: 51.92%
# Fold 5/5 Epoch 7/20 | Training Accuracy: 47.26% | Validation Accuracy: 37.48%
# Fold 5/5 Epoch 8/20 | Training Accuracy: 48.05% | Validation Accuracy: 49.72%
# Fold 5/5 Epoch 9/20 | Training Accuracy: 47.83% | Validation Accuracy: 43.70%
# Fold 5/5 Epoch 10/20 | Training Accuracy: 46.74% | Validation Accuracy: 38.52%
# Fold 5/5 Epoch 11/20 | Training Accuracy: 46.19% | Validation Accuracy: 54.33%
# Fold 5/5 Epoch 12/20 | Training Accuracy: 46.87% | Validation Accuracy: 57.69%
# Fold 5/5 Epoch 13/20 | Training Accuracy: 46.63% | Validation Accuracy: 50.75%
# Fold 5/5 Epoch 14/20 | Training Accuracy: 47.02% | Validation Accuracy: 48.42%
# Fold 5/5 Epoch 15/20 | Training Accuracy: 45.69% | Validation Accuracy: 56.03%
# Fold 5/5 Epoch 16/20 | Training Accuracy: 47.89% | Validation Accuracy: 54.08%
# Fold 5/5 Epoch 17/20 | Training Accuracy: 47.53% | Validation Accuracy: 54.17%
# Fold 5/5 Epoch 18/20 | Training Accuracy: 47.03% | Validation Accuracy: 29.04%
# Fold 5/5 Epoch 19/20 | Training Accuracy: 46.58% | Validation Accuracy: 35.21%
# Best trial: 14. Best value: 0.9559: 100%|██████████| 20/20 [7:04:22<00:00, 1273.15s/it]
# Fold 5/5 Epoch 20/20 | Training Accuracy: 48.02% | Validation Accuracy: 58.48%
#     Fold 5 Best Val Acc: 0.5847 (58.48)%
#     Fold 5 Total Training Time: 4.30 mins.
#     All Folds Completion Total Training Time: 20.88 mins.
# Best configuration: {'lr': 0.0008837377743583721, 'alpha': 0.8824966424677287, 'eps': 1.0832281439392694e-09, 'momentum': 0.6248377417848384, 'weight_decay': 1.0567445644797476e-05}
# Mean Validation Accuracy: 0.9559

# %%
train_loss_config_map
# Out:
# {'config_1': "{'lr': 0.0019476838464710998, 'alpha': 0.800025289324904, 'eps': 1.1392983025644397e-07, 'momentum': 0.3701973165945234, 'weight_decay': 0.008424534983398027}",
#  'config_2': "{'lr': 0.0002705494845786357, 'alpha': 0.8024846649464388, 'eps': 4.198054585997742e-09, 'momentum': 0.37094913506955823, 'weight_decay': 0.0002894154724905874}",
#  'config_3': "{'lr': 0.026640584134882614, 'alpha': 0.8032514072130412, 'eps': 9.270481985035688e-09, 'momentum': 0.0846827861457791, 'weight_decay': 0.001360555088824136}",
#  'config_4': "{'lr': 0.034980420096149156, 'alpha': 0.9781040889843617, 'eps': 4.979793789604447e-07, 'momentum': 0.08872365680660942, 'weight_decay': 0.0012181438359676958}",
#  'config_5': "{'lr': 0.0011600597275032583, 'alpha': 0.8218467767968733, 'eps': 2.2189459466856255e-09, 'momentum': 0.742988986089937, 'weight_decay': 1.0528704406305239e-05}",
#  'config_6': "{'lr': 0.000768535818087759, 'alpha': 0.9042889462647967, 'eps': 9.41157015652493e-08, 'momentum': 0.673943614017454, 'weight_decay': 0.0019084424978012544}",
#  'config_7': "{'lr': 0.0002334045588745601, 'alpha': 0.8940495196165702, 'eps': 4.4149719128883496e-08, 'momentum': 0.08237981675673965, 'weight_decay': 0.00042734085143992894}",
#  'config_8': "{'lr': 1.2404761911649825e-05, 'alpha': 0.9788952427470539, 'eps': 2.024479373363253e-09, 'momentum': 0.0907740093921802, 'weight_decay': 2.829317153761786e-05}",
#  'config_9': "{'lr': 0.0002550150677454392, 'alpha': 0.80389512838779, 'eps': 3.986609347193261e-08, 'momentum': 0.4143386878657271, 'weight_decay': 9.601853921513595e-05}",
#  'config_10': "{'lr': 0.00019303211473271065, 'alpha': 0.8016473102350582, 'eps': 1.0647457307653659e-09, 'momentum': 0.1198568520124796, 'weight_decay': 0.0005523698410613538}",
#  'config_11': "{'lr': 0.006011183112880236, 'alpha': 0.8599834287351458, 'eps': 7.376919810051015e-07, 'momentum': 0.8711558869622029, 'weight_decay': 1.0265162904399288e-05}",
#  'config_12': "{'lr': 3.5621346912319085e-05, 'alpha': 0.8477740400140249, 'eps': 4.84430111698863e-09, 'momentum': 0.5868313213886879, 'weight_decay': 9.914886573284521e-05}",
#  'config_13': "{'lr': 0.0034203568468211955, 'alpha': 0.8411710612200827, 'eps': 7.387250959134082e-09, 'momentum': 0.8623258136563945, 'weight_decay': 9.980396672648531e-05}",
#  'config_14': "{'lr': 0.0008147881236065796, 'alpha': 0.8385344255851751, 'eps': 2.9884607395327503e-09, 'momentum': 0.31785473211953924, 'weight_decay': 1.1508825568035366e-05}",
#  'config_15': "{'lr': 0.0008837377743583721, 'alpha': 0.8824966424677287, 'eps': 1.0832281439392694e-09, 'momentum': 0.6248377417848384, 'weight_decay': 1.0567445644797476e-05}",
#  'config_16': "{'lr': 6.238519405532185e-05, 'alpha': 0.8933857765547827, 'eps': 1.062935454079886e-09, 'momentum': 0.5076616613931555, 'weight_decay': 2.738803779912171e-05}",
#  'config_17': "{'lr': 0.010139043461371558, 'alpha': 0.9243817924969993, 'eps': 1.3303985420504914e-08, 'momentum': 0.21424910543600087, 'weight_decay': 2.9396934588483122e-05}",
#  'config_18': "{'lr': 0.000589660205181521, 'alpha': 0.8699150195184332, 'eps': 2.919906946131479e-09, 'momentum': 0.23781766261182363, 'weight_decay': 1.7508689909851672e-05}",
#  'config_19': "{'lr': 0.01037420938580816, 'alpha': 0.9358530901270731, 'eps': 1.7719748836962326e-08, 'momentum': 0.5307023721463947, 'weight_decay': 5.483216492741157e-05}",
#  'config_20': "{'lr': 0.08865248939830234, 'alpha': 0.877904111217427, 'eps': 1.0372615023712756e-09, 'momentum': 0.7403977275232295, 'weight_decay': 5.28516736707329e-05}"}

# %%
val_loss_configs_map
# Out:
# {'config_1': "{'lr': 0.0019476838464710998, 'alpha': 0.800025289324904, 'eps': 1.1392983025644397e-07, 'momentum': 0.3701973165945234, 'weight_decay': 0.008424534983398027}",
#  'config_2': "{'lr': 0.0002705494845786357, 'alpha': 0.8024846649464388, 'eps': 4.198054585997742e-09, 'momentum': 0.37094913506955823, 'weight_decay': 0.0002894154724905874}",
#  'config_3': "{'lr': 0.026640584134882614, 'alpha': 0.8032514072130412, 'eps': 9.270481985035688e-09, 'momentum': 0.0846827861457791, 'weight_decay': 0.001360555088824136}",
#  'config_4': "{'lr': 0.034980420096149156, 'alpha': 0.9781040889843617, 'eps': 4.979793789604447e-07, 'momentum': 0.08872365680660942, 'weight_decay': 0.0012181438359676958}",
#  'config_5': "{'lr': 0.0011600597275032583, 'alpha': 0.8218467767968733, 'eps': 2.2189459466856255e-09, 'momentum': 0.742988986089937, 'weight_decay': 1.0528704406305239e-05}",
#  'config_6': "{'lr': 0.000768535818087759, 'alpha': 0.9042889462647967, 'eps': 9.41157015652493e-08, 'momentum': 0.673943614017454, 'weight_decay': 0.0019084424978012544}",
#  'config_7': "{'lr': 0.0002334045588745601, 'alpha': 0.8940495196165702, 'eps': 4.4149719128883496e-08, 'momentum': 0.08237981675673965, 'weight_decay': 0.00042734085143992894}",
#  'config_8': "{'lr': 1.2404761911649825e-05, 'alpha': 0.9788952427470539, 'eps': 2.024479373363253e-09, 'momentum': 0.0907740093921802, 'weight_decay': 2.829317153761786e-05}",
#  'config_9': "{'lr': 0.0002550150677454392, 'alpha': 0.80389512838779, 'eps': 3.986609347193261e-08, 'momentum': 0.4143386878657271, 'weight_decay': 9.601853921513595e-05}",
#  'config_10': "{'lr': 0.00019303211473271065, 'alpha': 0.8016473102350582, 'eps': 1.0647457307653659e-09, 'momentum': 0.1198568520124796, 'weight_decay': 0.0005523698410613538}",
#  'config_11': "{'lr': 0.006011183112880236, 'alpha': 0.8599834287351458, 'eps': 7.376919810051015e-07, 'momentum': 0.8711558869622029, 'weight_decay': 1.0265162904399288e-05}",
#  'config_12': "{'lr': 3.5621346912319085e-05, 'alpha': 0.8477740400140249, 'eps': 4.84430111698863e-09, 'momentum': 0.5868313213886879, 'weight_decay': 9.914886573284521e-05}",
#  'config_13': "{'lr': 0.0034203568468211955, 'alpha': 0.8411710612200827, 'eps': 7.387250959134082e-09, 'momentum': 0.8623258136563945, 'weight_decay': 9.980396672648531e-05}",
#  'config_14': "{'lr': 0.0008147881236065796, 'alpha': 0.8385344255851751, 'eps': 2.9884607395327503e-09, 'momentum': 0.31785473211953924, 'weight_decay': 1.1508825568035366e-05}",
#  'config_15': "{'lr': 0.0008837377743583721, 'alpha': 0.8824966424677287, 'eps': 1.0832281439392694e-09, 'momentum': 0.6248377417848384, 'weight_decay': 1.0567445644797476e-05}",
#  'config_16': "{'lr': 6.238519405532185e-05, 'alpha': 0.8933857765547827, 'eps': 1.062935454079886e-09, 'momentum': 0.5076616613931555, 'weight_decay': 2.738803779912171e-05}",
#  'config_17': "{'lr': 0.010139043461371558, 'alpha': 0.9243817924969993, 'eps': 1.3303985420504914e-08, 'momentum': 0.21424910543600087, 'weight_decay': 2.9396934588483122e-05}",
#  'config_18': "{'lr': 0.000589660205181521, 'alpha': 0.8699150195184332, 'eps': 2.919906946131479e-09, 'momentum': 0.23781766261182363, 'weight_decay': 1.7508689909851672e-05}",
#  'config_19': "{'lr': 0.01037420938580816, 'alpha': 0.9358530901270731, 'eps': 1.7719748836962326e-08, 'momentum': 0.5307023721463947, 'weight_decay': 5.483216492741157e-05}",
#  'config_20': "{'lr': 0.08865248939830234, 'alpha': 0.877904111217427, 'eps': 1.0372615023712756e-09, 'momentum': 0.7403977275232295, 'weight_decay': 5.28516736707329e-05}"}

# %% [markdown]
# # Branch TODO 3
# Modify the code below to suit the selected optimizer (Adam, RMSProp, AdamW).
# This code should already retrieve the best configurations tested in TODO 2, but please double check that this is the case.
# Adjust other parameters such as the TARGET_ACC as needed; it's currently set to 0.6 for testing purposes.

# %%
# Final training with best configurations using full training set

# Refresh seeding and model.
torch.manual_seed(MANUAL_SEED)
final_model = FeedForwardNet().to(device)


final_optimizer = torch.optim.RMSprop(final_model.parameters(), **best_config_params)
loss_function = torch.nn.CrossEntropyLoss()

# Use all of the training dataset + the held-out test set
full_train_loader = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
testloader = DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False)

# 5.4 & 6.2 Req: Track losses and accuracies
train_losses = []
train_accuracies  = []
test_losses = []
test_accuracies = []

# To check convergence speed
convergence_epoch = None

# This ensures time will be synchronized, does not affect GPU performance.
if device.type == "cuda":
    torch.cuda.synchronize()

# Log start time
start_time = time.perf_counter()

for epoch in range(EPOCHS):
    train_loss, train_acc = run_epoch(
        final_model, full_train_loader, loss_function, final_optimizer, device, training=True
    )

    # 5.3 Req: Evaluate the final trained model exactly once on the held-out test data
    test_loss, test_acc = run_epoch(
        final_model, testloader, loss_function, optimizer=None, device=device, training=False
    )

    # Store metrics for plotting later
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies.append(test_acc)
    
    # Req 5.4: Identify Convergence Epoch
    if test_acc >= TARGET_ACC and convergence_epoch is None:
        convergence_epoch = epoch + 1  # 0-index
        
    print(f"Epoch {epoch + 1}/{EPOCHS}")
    print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
    print(f"Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.4f}")

# Stop time
if device.type == "cuda":
    torch.cuda.synchronize()
end_time = time.perf_counter()

# 5.4 Req: Training Time
total_training_time = end_time - start_time

# 5.4 Req: Final Training and Testing Losses
final_train_acc = train_accuracies[-1]
final_test_acc = test_accuracies[-1]

# 5.4 Req: Final Training and Testing Accuracies
final_train_loss = train_losses[-1]
final_test_loss = test_losses[-1]

# If the model never reached the target threshold, default to the max epochs run
if convergence_epoch is None:
    convergence_epoch = EPOCHS
# Out:
# Epoch 1/20
# Train Loss: 0.4823 | Train Acc: 0.8498
# Test Loss: 0.5236 | Test Acc: 0.8339
# Epoch 2/20
# Train Loss: 0.3189 | Train Acc: 0.9019
# Test Loss: 0.4755 | Test Acc: 0.8512
# Epoch 3/20
# Train Loss: 0.2702 | Train Acc: 0.9164
# Test Loss: 0.4184 | Test Acc: 0.8776
# Epoch 4/20
# Train Loss: 0.2426 | Train Acc: 0.9244
# Test Loss: 0.3821 | Test Acc: 0.8873
# Epoch 5/20
# Train Loss: 0.2259 | Train Acc: 0.9306
# Test Loss: 0.4175 | Test Acc: 0.8761
# Epoch 6/20
# Train Loss: 0.2109 | Train Acc: 0.9347
# Test Loss: 0.4027 | Test Acc: 0.8906
# Epoch 7/20
# Train Loss: 0.2025 | Train Acc: 0.9374
# Test Loss: 0.4166 | Test Acc: 0.8830
# Epoch 8/20
# Train Loss: 0.1965 | Train Acc: 0.9383
# Test Loss: 0.3846 | Test Acc: 0.8880
# Epoch 9/20
# Train Loss: 0.1848 | Train Acc: 0.9416
# Test Loss: 0.3899 | Test Acc: 0.8885
# Epoch 10/20
# Train Loss: 0.1822 | Train Acc: 0.9436
# Test Loss: 0.3927 | Test Acc: 0.8908
# Epoch 11/20
# Train Loss: 0.1731 | Train Acc: 0.9455
# Test Loss: 0.3769 | Test Acc: 0.8980
# Epoch 12/20
# Train Loss: 0.1691 | Train Acc: 0.9464
# Test Loss: 0.3785 | Test Acc: 0.8958
# Epoch 13/20
# Train Loss: 0.1631 | Train Acc: 0.9482
# Test Loss: 0.4074 | Test Acc: 0.8931
# Epoch 14/20
# Train Loss: 0.1629 | Train Acc: 0.9479
# Test Loss: 0.3718 | Test Acc: 0.9011
# Epoch 15/20
# Train Loss: 0.1558 | Train Acc: 0.9508
# Test Loss: 0.3810 | Test Acc: 0.8978
# Epoch 16/20
# Train Loss: 0.1534 | Train Acc: 0.9506
# Test Loss: 0.3869 | Test Acc: 0.8979
# Epoch 17/20
# Train Loss: 0.1527 | Train Acc: 0.9524
# Test Loss: 0.3869 | Test Acc: 0.8980
# Epoch 18/20
# Train Loss: 0.1545 | Train Acc: 0.9503
# Test Loss: 0.3916 | Test Acc: 0.8998
# Epoch 19/20
# Train Loss: 0.1482 | Train Acc: 0.9532
# Test Loss: 0.4005 | Test Acc: 0.8972
# Epoch 20/20
# Train Loss: 0.1428 | Train Acc: 0.9546
# Test Loss: 0.3965 | Test Acc: 0.8989

# %% [markdown]
# # 6. Results
# ### 6.1  Summary Table
# Present a table comparing the best configuration of each optimizer across all metrics defined in Section 5.4. Include both default and best configurations for each optimizer.
#
# ### 6.2  Required Plots
# - Training and validation loss curves over epochs for the best configuration of each optimizer
# (all three on one plot for direct comparison).
# - Training and validation accuracy curves over epochs.
# - Bar chart comparing final test accuracy across optimizers.
# - Box plot or error-bar plot showing the cross-validation accuracy distribution for each optimizer.
# - Optional: learning-rate sensitivity plot showing validation accuracy vs. learning rate for each optimizer.
#
# ### 6.3  Reproducibility
# - State the random seed used.
# - Specify library versions (Python, PyTorch, torchvision).
# - Confirm that results in the report can be reproduced by running the submitted code with no
# modifications.

# %%
# 6.1 Requirement Placeholder
# Sample Metric Report (for now)
print("\n" + "="*40)
print("FINAL PRODUCTION RUN METRICS LOG")
print("="*40)
print(f"1. Training Accuracy (Final Epoch): {final_train_acc * 100:.2f}%")
print(f"2. Cross-Validation Accuracy: Mean: {best_config_data[0]:.4f}; Standard Dev: {best_config_data[1]:.4f}")
print(f"3. Test Accuracy: {final_test_acc * 100:.2f}%")
print(f"4. Final Loss:")
print(f"   - Final Training Loss:{final_train_loss:.4f}")
print(f"   - Final Test Loss: {final_test_loss:.4f}")
print(f"5. Convergence Speed: {convergence_epoch} epochs to reach {TARGET_ACC * 100:.0f}% train accuracy")
print(f"6. Total Training Time: {total_training_time:.2f} seconds")
print("="*40)
# Out:
# ========================================
# FINAL PRODUCTION RUN METRICS LOG
# ========================================
# 1. Training Accuracy (Final Epoch): 95.46%
# 2. Cross-Validation Accuracy: Mean: 0.9579; Standard Dev: 0.0021
# 3. Test Accuracy: 89.89%
# 4. Final Loss:
#    - Final Training Loss:0.1428
#    - Final Test Loss: 0.3965
# 5. Convergence Speed: 1 epochs to reach 60% train accuracy
# 6. Total Training Time: 81.70 seconds
# ========================================

# %% [markdown]
# ### Final Report TODO:
# Based on the requirements mentioned in 6.2, we will need to include all three optimizers in the same notebook. Otherwise, we won't be able to compare them side by side in these plots.

# %% [markdown]
# # Branch TODO 4
# Use the following graph templates to visualize the results for your optimizer.
# Notice that the architecture assumes all three optimizers will be compared in some of the graphs; in this case, double check that the information being populated for the y axis is in the correct order. Currently the placeholder code assumes Adam in index 0.

# %%
# 6.2: Training and validation loss curves over epochs for the best configuration of each optimizer 
# (all three on one plot for direct comparison).
x = range(EPOCHS)
plt.figure(figsize=(12, 8))
plt.plot(x, train_losses, marker='x', color='g', label='Train Loss')
plt.plot(x, test_losses, marker='o', color='b', label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Cross Entropy Loss')
plt.title('Train & Test Loss over Epochs')
plt.legend()
plt.show()

# %%
# 6.2: Training and validation accuracy curves over epochs.
x = range(EPOCHS)
plt.figure(figsize=(12, 8))
plt.plot(x, train_accuracies, marker='x', color='g', label='Train Accuracy')
plt.plot(x, test_accuracies, marker='o', color='b', label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Train & Test Accuracies over Epochs')
plt.legend()
plt.show()

# %%
# 6.2: Bar chart comparing final test accuracy across optimizers.
# Placeholder code for now. Will add all optimizers later.
x = ['Adam', 'RMSProp', 'AdamW']
y = [final_test_acc, TARGET_ACC, TARGET_ACC]
plt.figure(figsize=(12, 8))
plt.bar(x, y)
plt.xlabel('Optimizers')
plt.ylabel('Accuracy')
plt.title('Final Accuracy by Optimizer')
plt.show()

# %%
# 6.2: Box plot or error-bar plot showing the cross-validation accuracy distribution for each optimizer.
# Use Error Bar Plot since we only have mean and standard deviations

# Placeholder code for now; will update with all optimizers later.
means = [best_config_data[0], 0.5, 0.8]
stddevs = [best_config_data[1], 0.1, 0.05]

# Define size
plt.figure(figsize=(12, 8))

# Plot the error bar
plt.errorbar(x=x, y=means, yerr=stddevs, fmt='o', color='green', ecolor='red', label= 'CV Accuracy (Mean ± SD)')
plt.title('Cross Validation Accuracy Distribution by Optimizer')
plt.xlabel('Optimizer')
plt.ylabel('Validation Accuracy')

# %%
# 6.2: Optional: learning-rate sensitivity plot showing validation accuracy vs. learning rate for each optimizer.

# %%
# 6.3 Reproducibility
# Final Report TODO: Will add later.

# %% [markdown]
# # 7. Interpretation and Discussion
# ### 7.1  Optimizer Analysis
# - Describe the convergence behaviour of each optimizer. Which converged fastest? Which was
# most stable?
# - Discuss  how  each  optimizer  responded  to  learning  rate  changes.  Was  any  optimizer
# particularly sensitive or robust?
# - Compare the generalization gap (train accuracy vs. test accuracy) across optimizers. What
# might explain the differences?
#
# ### 7.2  Weight Decay and Regularization
# - Explain,  with  reference  to  your  results,  how  decoupled  weight  decay  in  AdamW  affects
# generalization compared with Adam.
# - If AdamW did not outperform Adam in your experiment, provide a hypothesis for why.
#
# ### 7.3  Conclusion and Recommendation
# - State clearly which optimizer performed best on KMNIST and why.
# - Suggest when you would choose each optimizer in a real-world scenario, beyond this specific
# task.
# - Identify at least two limitations of your experimental design and suggest how future work could address them.

# %% [markdown]
# # Branch TODO 5
# For each of the sections below, conduct analyses based solely on the optimizer chosen first. Ignore the comparisons for now; for instance, just describe the convergence behavior of the selected optimizer (e.g., RMSProp) on its own while including empirical values; these values will be helpful later as we synthesize the findings for the comparison.

# %%
# 7.1 Optimizer Analysis (Single Focus)
# Add information about the convergence behavior of the single optimizer
# Add information about how the optimizer responded to learning rate changes
# Add information about the generalization gap within the single optimizer.

# %%
# 7.2 Weight Decay & Regularization (Not Applicable)

# %%
# 7.3 Conclusion & Recommendation
# Add information about when the optimizer might be chosen for a real-world scenario.
# Identify one limitation in the experimental design with respect to the optimizer
# Suggest how future work may address the limitation.
